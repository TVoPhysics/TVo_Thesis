# %%
# %matplotlib inline
import pykat
import pylab as pl
import pandas
import matplotlib.pyplot as plt
import matplotlib
import csv
import math
import numpy as np
from pykat.parallel import parakat
import pprint

pandas.set_eng_float_format(accuracy=3, use_eng_prefix=True)

# %%
#Perfct Mode-Matching Conditions

katfile = './aLIGO_IFO_AWC_tuning_DCoff_maxtem4.kat'
basekat = pykat.finesse.kat()
basekat.loadKatFile(katfile)

basekat.parseCommands("""
tf sus 1 0 p $mech_fres $mech_Q
const mech_fres 1  # Approx. resonance frequency
const mech_Q    1M # Guess for suspension Q factor

# Differentially modulate the strain in the arms
fsig darm  LXarm 1 0 1
fsig darm2 LYarm 1 180 1

#sq sqz 0 10 0 nsqz

qnoisedS NSR_with_RP    1 $fs nOMC_AROC_trans
xaxis darm f log 5 5k 50
yaxis re:im
""")

basekat.undumpNodes() #undump the vacuum nodes
kat=basekat.deepcopy() #copy kat code

trace_out = kat.run(getTraceData=True)

out = kat.run()
# Out:
# Parsing `put lx1 L $Lmx` into pykat object not implemented yet, added as extra line.
# Parsing `put ly1 L $Lmy` into pykat object not implemented yet, added as extra line.
# --------------------------------------------------------------
# Running kat - Started at 2016-08-23 17:16:15.797418
#  99% | ETA:  0:00:00 | Calculating
# Finished in 15.9668 seconds
# --------------------------------------------------------------
# Running kat - Started at 2016-08-23 17:16:31.764679
#
# Finished in 13.5079 seconds
#  99% | ETA:  0:00:00 | Calculating

# %%
vars(trace_out[1][0]['nAOE1trans'][1])
# Out:
# {'_gauss_param__lambda': 1.064e-06,
#  '_gauss_param__nr': 1.0,
#  '_gauss_param__q': (0.449490696453873+13.3411754581134j)}

# %%
# [access object][trace data]['name']
outdict = trace_out[1][0]

# %%
# [access object][trace data]
outdict = trace_out[1][0]

#parse the output to name and q's
dictlist = []
for key, value in outdict.items():
    temp = [key,value]
    dictlist.append(temp)


nodename_list = []
q_x_list = []
q_y_list = []

#[node_list][key/parameters][x/y]
for i in range(len(dictlist)):
    nodename_list.append(dictlist[i][0])
    q_x_list.append(dictlist[i][1][0]._gauss_param__q)
    q_y_list.append(dictlist[i][1][1]._gauss_param__q)

# %%
dir(outdict['dump_0'][0])
# Out:
# ['Rc',
#  '__abs__',
#  '__add__',
#  '__class__',
#  '__complex__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__isub__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_gauss_param__lambda',
#  '_gauss_param__nr',
#  '_gauss_param__q',
#  'beamsize',
#  'conjugate',
#  'curvature',
#  'gouy',
#  'imag',
#  'nr',
#  'overlap',
#  'q',
#  'real',
#  'reverse',
#  'w',
#  'w0',
#  'wavelength',
#  'z',
#  'zr']

# %%
comp_node_list = []

for key in kat.components:
    node0 = kat.components[key].nodes[0].name
    try:
        node1 = kat.components[key].nodes[1].name
    except:
        continue
    comp_node_list.append([key,node0,node1])

# %%
dir(kat.components['PR3'])
# Out:
# ['Frx',
#  'Fry',
#  'Fz',
#  'Ix',
#  'Iy',
#  'L',
#  'R',
#  'Rc',
#  'Rcx',
#  'Rcy',
#  'T',
#  '_AbstractMirrorComponent__Frx',
#  '_AbstractMirrorComponent__Fry',
#  '_AbstractMirrorComponent__Fs0',
#  '_AbstractMirrorComponent__Fs1',
#  '_AbstractMirrorComponent__Fz',
#  '_AbstractMirrorComponent__Ix',
#  '_AbstractMirrorComponent__Iy',
#  '_AbstractMirrorComponent__L',
#  '_AbstractMirrorComponent__R',
#  '_AbstractMirrorComponent__Rcx',
#  '_AbstractMirrorComponent__Rcy',
#  '_AbstractMirrorComponent__T',
#  '_AbstractMirrorComponent__mass',
#  '_AbstractMirrorComponent__phi',
#  '_AbstractMirrorComponent__r_ap',
#  '_AbstractMirrorComponent__rx',
#  '_AbstractMirrorComponent__rxmech',
#  '_AbstractMirrorComponent__ry',
#  '_AbstractMirrorComponent__rymech',
#  '_AbstractMirrorComponent__xbeta',
#  '_AbstractMirrorComponent__ybeta',
#  '_AbstractMirrorComponent__z',
#  '_AbstractMirrorComponent__zmech',
#  '_Component__add_node_setter',
#  '_Component__get_node_setter',
#  '_Component__id',
#  '_Component__name',
#  '_Component__on_node_change',
#  '_Component__removed',
#  '_Component__update_node_setters',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nodesetter_dump_0',
#  '__nodesetter_dump_1',
#  '__nodesetter_nPR3a',
#  '__nodesetter_nPR3b',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_beamSplitter__alpha',
#  '_default_fsig',
#  '_default_fsig_param',
#  '_kat',
#  '_on_kat_add',
#  '_optivis_component',
#  '_params',
#  '_register_param',
#  '_requested_node_names',
#  '_svgItem',
#  'alpha',
#  'dump_0',
#  'dump_1',
#  'getFinesseText',
#  'getOptivisComponent',
#  'getOptivisNode',
#  'getOptivisParameterDict',
#  'getOptivisTooltip',
#  'getQGraphicsItem',
#  'id',
#  'mass',
#  'nPR3a',
#  'nPR3b',
#  'name',
#  'nodes',
#  'optivisLabelContent',
#  'parseAttribute',
#  'parseAttributes',
#  'parseFinesseText',
#  'phi',
#  'r_ap',
#  'remove',
#  'removed',
#  'rx',
#  'rxmech',
#  'ry',
#  'rymech',
#  'setOptivisLabelContent',
#  'tag',
#  'xbeta',
#  'ybeta',
#  'z',
#  'zmech']

# %%
kat.nodes.nAOE1in

# %%
vars(kat.nodes.nAOE1in.network)
# Out:
# {'_NodeNetwork__componentCallback': {876: <bound method Component.__on_node_change of <pykat.components.pykat.components.laser_1916 object at 0x7fa6180b8550>>,
#   877: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1948 object at 0x7fa618677d68>>,
#   878: <bound method Component.__on_node_change of <pykat.components.pykat.components.modulator_1913 object at 0x7fa6186accf8>>,
#   879: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1998 object at 0x7fa611427668>>,
#   880: <bound method Component.__on_node_change of <pykat.components.pykat.components.modulator_2000 object at 0x7fa6186a0630>>,
#   881: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1895 object at 0x7fa6186cb7f0>>,
#   882: <bound method Component.__on_node_change of <pykat.components.pykat.components.modulator_1954 object at 0x7fa6180a1f98>>,
#   883: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1966 object at 0x7fa61145c908>>,
#   884: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1959 object at 0x7fa61142f390>>,
#   885: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1957 object at 0x7fa61142f9b0>>,
#   886: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1971 object at 0x7fa6180afda0>>,
#   887: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1958 object at 0x7fa61142ff60>>,
#   888: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1963 object at 0x7fa611425860>>,
#   889: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1992 object at 0x7fa6183b5ef0>>,
#   890: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1903 object at 0x7fa6186d5e80>>,
#   891: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1981 object at 0x7fa61144aac8>>,
#   892: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1889 object at 0x7fa6186d3c18>>,
#   893: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1970 object at 0x7fa619052e48>>,
#   894: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1990 object at 0x7fa6183b5dd8>>,
#   895: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1960 object at 0x7fa6183e8d30>>,
#   896: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1884 object at 0x7fa618099710>>,
#   897: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1896 object at 0x7fa6186cb9b0>>,
#   898: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1942 object at 0x7fa6183c0f98>>,
#   899: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1976 object at 0x7fa6186b58d0>>,
#   900: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1962 object at 0x7fa6114251d0>>,
#   901: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1908 object at 0x7fa6186c0208>>,
#   902: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1904 object at 0x7fa6186d5780>>,
#   903: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1994 object at 0x7fa6183b5be0>>,
#   904: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1891 object at 0x7fa6186cb0b8>>,
#   905: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1922 object at 0x7fa6180ddeb8>>,
#   906: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1956 object at 0x7fa611439438>>,
#   907: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1953 object at 0x7fa6114394e0>>,
#   908: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1892 object at 0x7fa6186cbcc0>>,
#   909: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1952 object at 0x7fa6114396d8>>,
#   910: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1989 object at 0x7fa618426a20>>,
#   911: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1939 object at 0x7fa618088c50>>,
#   912: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1936 object at 0x7fa6180e5518>>,
#   913: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1985 object at 0x7fa6184265c0>>,
#   914: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1898 object at 0x7fa6186ba2e8>>,
#   915: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1883 object at 0x7fa6186d0b00>>,
#   916: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1944 object at 0x7fa6186770f0>>,
#   917: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1890 object at 0x7fa6186d33c8>>,
#   918: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1876 object at 0x7fa61868eda0>>,
#   919: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1907 object at 0x7fa6186c0898>>,
#   920: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1933 object at 0x7fa6183cce80>>,
#   921: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1961 object at 0x7fa611425320>>,
#   922: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1978 object at 0x7fa6191574e0>>,
#   923: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1940 object at 0x7fa618088e10>>,
#   924: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1894 object at 0x7fa6186cbcf8>>,
#   925: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1988 object at 0x7fa618426cc0>>,
#   926: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1950 object at 0x7fa6180a1048>>,
#   927: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1977 object at 0x7fa6186b5588>>,
#   928: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1941 object at 0x7fa6183c0128>>,
#   929: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1877 object at 0x7fa619157eb8>>,
#   930: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1964 object at 0x7fa61145c9b0>>,
#   931: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1879 object at 0x7fa6180da0f0>>,
#   932: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1972 object at 0x7fa6183bbdd8>>,
#   933: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1967 object at 0x7fa61145ccc0>>,
#   934: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1900 object at 0x7fa6186ba550>>,
#   935: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1901 object at 0x7fa6186d5be0>>,
#   936: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1997 object at 0x7fa618099d30>>,
#   937: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1888 object at 0x7fa6186d3470>>,
#   938: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1999 object at 0x7fa611427390>>,
#   939: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1937 object at 0x7fa6184207b8>>,
#   940: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1979 object at 0x7fa6186b5a20>>,
#   941: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1902 object at 0x7fa6186d5eb8>>,
#   942: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1923 object at 0x7fa6186822e8>>,
#   943: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1919 object at 0x7fa6186862b0>>,
#   944: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1996 object at 0x7fa611427e80>>,
#   945: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1984 object at 0x7fa618426940>>,
#   946: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1928 object at 0x7fa612d160f0>>,
#   947: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1914 object at 0x7fa6186ac5c0>>,
#   948: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1931 object at 0x7fa618090dd8>>,
#   949: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1930 object at 0x7fa6184e0d68>>,
#   950: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1880 object at 0x7fa61868ee10>>,
#   951: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1915 object at 0x7fa6186ac358>>,
#   952: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1982 object at 0x7fa61144a668>>,
#   953: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1934 object at 0x7fa61915d0f0>>,
#   954: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1991 object at 0x7fa6183b5f98>>,
#   955: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1906 object at 0x7fa6186c0160>>,
#   956: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1974 object at 0x7fa6183bb7b8>>,
#   957: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1980 object at 0x7fa61144ab00>>,
#   958: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1905 object at 0x7fa618090748>>,
#   959: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1927 object at 0x7fa618684080>>,
#   960: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1926 object at 0x7fa61809df28>>,
#   961: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1921 object at 0x7fa618686d68>>,
#   962: <bound method Component.__on_node_change of <pykat.components.pykat.components.isolator_1881 object at 0x7fa618099048>>,
#   963: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1929 object at 0x7fa6184784e0>>,
#   964: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1885 object at 0x7fa6186d0e48>>,
#   965: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1932 object at 0x7fa6183cc7b8>>,
#   966: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1917 object at 0x7fa6180fb198>>,
#   967: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1968 object at 0x7fa618099dd8>>,
#   968: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1887 object at 0x7fa6186d3780>>,
#   969: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1993 object at 0x7fa6183b5470>>,
#   970: <bound method Component.__on_node_change of <pykat.components.pykat.components.mirror_1955 object at 0x7fa611439748>>,
#   971: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1909 object at 0x7fa6180a1198>>,
#   972: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1949 object at 0x7fa618677fd0>>,
#   973: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1918 object at 0x7fa618686588>>,
#   974: <bound method Component.__on_node_change of <pykat.components.pykat.components.lens_1910 object at 0x7fa618090e48>>,
#   975: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1878 object at 0x7fa61868e208>>,
#   976: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1882 object at 0x7fa6186d0390>>,
#   977: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1897 object at 0x7fa6186cbb38>>,
#   978: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1973 object at 0x7fa6183bb470>>,
#   979: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1969 object at 0x7fa619052128>>,
#   980: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1946 object at 0x7fa618677128>>,
#   981: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1986 object at 0x7fa618426780>>,
#   982: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1920 object at 0x7fa618686940>>,
#   983: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1975 object at 0x7fa6186b51d0>>,
#   984: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1938 object at 0x7fa618420e48>>,
#   985: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1945 object at 0x7fa618677240>>,
#   986: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1911 object at 0x7fa6186ac978>>,
#   987: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1912 object at 0x7fa6186ac1d0>>,
#   988: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1886 object at 0x7fa6186d3400>>,
#   989: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1951 object at 0x7fa611418588>>,
#   990: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1947 object at 0x7fa618677e10>>,
#   991: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1925 object at 0x7fa618ef3320>>,
#   992: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1983 object at 0x7fa618426c18>>,
#   993: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1924 object at 0x7fa6186824a8>>,
#   994: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1987 object at 0x7fa618426080>>,
#   995: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1899 object at 0x7fa6186bafd0>>,
#   996: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1893 object at 0x7fa6186cbda0>>,
#   997: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1943 object at 0x7fa6183c01d0>>,
#   998: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1995 object at 0x7fa6183b5cf8>>,
#   999: <bound method Component.__on_node_change of <pykat.components.pykat.components.beamSplitter_1935 object at 0x7fa61915d198>>,
#   1000: <bound method Component.__on_node_change of <pykat.components.pykat.components.space_1965 object at 0x7fa61145c978>>},
#  '_NodeNetwork__componentNodes': {876: (<pykat.node_network.Node at 0x7fa6186a1c50>,),
#   877: (<pykat.node_network.Node at 0x7fa6186a1c50>,
#    <pykat.node_network.Node at 0x7fa6184c42b0>),
#   878: (<pykat.node_network.Node at 0x7fa6184c42b0>,
#    <pykat.node_network.Node at 0x7fa6184c42e8>),
#   879: (<pykat.node_network.Node at 0x7fa6184c42e8>,
#    <pykat.node_network.Node at 0x7fa6184c4cf8>),
#   880: (<pykat.node_network.Node at 0x7fa6184c4cf8>,
#    <pykat.node_network.Node at 0x7fa6184c4860>),
#   881: (<pykat.node_network.Node at 0x7fa6184c4860>,
#    <pykat.node_network.Node at 0x7fa6186a1860>),
#   882: (<pykat.node_network.Node at 0x7fa6186a1860>,
#    <pykat.node_network.Node at 0x7fa6186a1320>),
#   883: (<pykat.node_network.Node at 0x7fa6186a1320>,
#    <pykat.node_network.Node at 0x7fa6186a0be0>),
#   884: (<pykat.node_network.Node at 0x7fa6186a0be0>,
#    <pykat.node_network.Node at 0x7fa6186a1588>,
#    <pykat.node_network.Node at 0x7fa6184c4780>,
#    <pykat.node_network.Node at 0x7fa6186a00f0>),
#   885: (<pykat.node_network.Node at 0x7fa6184c4780>,
#    <pykat.node_network.Node at 0x7fa6186a0160>),
#   886: (<pykat.node_network.Node at 0x7fa6186a0160>,
#    <pykat.node_network.Node at 0x7fa6186a1ac8>,
#    <pykat.node_network.Node at 0x7fa6186a0668>,
#    <pykat.node_network.Node at 0x7fa6186a1f60>),
#   887: (<pykat.node_network.Node at 0x7fa6186a1ac8>,
#    <pykat.node_network.Node at 0x7fa6186a04e0>),
#   888: (<pykat.node_network.Node at 0x7fa6186a04e0>,
#    <pykat.node_network.Node at 0x7fa6184c4f60>,
#    <pykat.node_network.Node at 0x7fa6186a09e8>,
#    <pykat.node_network.Node at 0x7fa6184c4a90>),
#   889: (<pykat.node_network.Node at 0x7fa6184c4f60>,
#    <pykat.node_network.Node at 0x7fa6186a00f0>),
#   890: (<pykat.node_network.Node at 0x7fa6186a09e8>,
#    <pykat.node_network.Node at 0x7fa6184c44e0>),
#   891: (<pykat.node_network.Node at 0x7fa6184c44e0>,
#    <pykat.node_network.Node at 0x7fa6186a1780>,
#    <pykat.node_network.Node at 0x7fa6186a0198>,
#    <pykat.node_network.Node at 0x7fa6186a1400>),
#   892: (<pykat.node_network.Node at 0x7fa6186a0198>,
#    <pykat.node_network.Node at 0x7fa6184c4940>),
#   893: (<pykat.node_network.Node at 0x7fa6184c4940>,
#    <pykat.node_network.Node at 0x7fa6186a0b70>,
#    <pykat.node_network.Node at 0x7fa6184c4f28>,
#    <pykat.node_network.Node at 0x7fa6186a1b70>),
#   894: (<pykat.node_network.Node at 0x7fa6184c4f28>,
#    <pykat.node_network.Node at 0x7fa6186a1da0>),
#   895: (<pykat.node_network.Node at 0x7fa6186a1da0>,
#    <pykat.node_network.Node at 0x7fa6184c4128>,
#    <pykat.node_network.Node at 0x7fa6186a1160>,
#    <pykat.node_network.Node at 0x7fa6186a06a0>),
#   896: (<pykat.node_network.Node at 0x7fa6186a1160>,
#    <pykat.node_network.Node at 0x7fa6184c4ef0>),
#   897: (<pykat.node_network.Node at 0x7fa6186a0b70>,
#    <pykat.node_network.Node at 0x7fa6186a1dd8>),
#   898: (<pykat.node_network.Node at 0x7fa6186a1dd8>,
#    <pykat.node_network.Node at 0x7fa6186a1898>),
#   899: (<pykat.node_network.Node at 0x7fa6186a1898>,
#    <pykat.node_network.Node at 0x7fa6186a1048>),
#   900: (<pykat.node_network.Node at 0x7fa6186a1048>,
#    <pykat.node_network.Node at 0x7fa6184c4d30>,
#    <pykat.node_network.Node at 0x7fa6184c4208>,
#    <pykat.node_network.Node at 0x7fa6186a1a20>),
#   901: (<pykat.node_network.Node at 0x7fa6184c4d30>,
#    <pykat.node_network.Node at 0x7fa6186a06d8>),
#   902: (<pykat.node_network.Node at 0x7fa6186a06d8>,
#    <pykat.node_network.Node at 0x7fa6186a1a90>,
#    <pykat.node_network.Node at 0x7fa6186a14e0>,
#    <pykat.node_network.Node at 0x7fa6186a1c88>),
#   903: (<pykat.node_network.Node at 0x7fa6186a1a90>,
#    <pykat.node_network.Node at 0x7fa6184c46d8>),
#   904: (<pykat.node_network.Node at 0x7fa6184c46d8>,
#    <pykat.node_network.Node at 0x7fa6186a01d0>),
#   905: (<pykat.node_network.Node at 0x7fa6186a01d0>,
#    <pykat.node_network.Node at 0x7fa6186a1be0>),
#   906: (<pykat.node_network.Node at 0x7fa6186a1be0>,
#    <pykat.node_network.Node at 0x7fa6186a1f28>,
#    <pykat.node_network.Node at 0x7fa6186a1d68>,
#    <pykat.node_network.Node at 0x7fa6186a12e8>),
#   907: (<pykat.node_network.Node at 0x7fa6186a1f28>,
#    <pykat.node_network.Node at 0x7fa6186a1fd0>),
#   908: (<pykat.node_network.Node at 0x7fa6186a1fd0>,
#    <pykat.node_network.Node at 0x7fa6184c45f8>),
#   909: (<pykat.node_network.Node at 0x7fa6184c45f8>,
#    <pykat.node_network.Node at 0x7fa6186a19b0>),
#   910: (<pykat.node_network.Node at 0x7fa6186a19b0>,
#    <pykat.node_network.Node at 0x7fa6186a0780>),
#   911: (<pykat.node_network.Node at 0x7fa6186a0780>,
#    <pykat.node_network.Node at 0x7fa6186a0400>),
#   912: (<pykat.node_network.Node at 0x7fa6186a0400>,
#    <pykat.node_network.Node at 0x7fa6184c4dd8>,
#    <pykat.node_network.Node at 0x7fa6186a1b38>,
#    <pykat.node_network.Node at 0x7fa6184c4ac8>),
#   913: (<pykat.node_network.Node at 0x7fa6184c4dd8>,
#    <pykat.node_network.Node at 0x7fa6184c45c0>),
#   914: (<pykat.node_network.Node at 0x7fa6184c45c0>,
#    <pykat.node_network.Node at 0x7fa6184c4fd0>,
#    <pykat.node_network.Node at 0x7fa6186a0860>,
#    <pykat.node_network.Node at 0x7fa6186a0d68>),
#   915: (<pykat.node_network.Node at 0x7fa6184c4fd0>,
#    <pykat.node_network.Node at 0x7fa6184c4668>),
#   916: (<pykat.node_network.Node at 0x7fa6184c4668>,
#    <pykat.node_network.Node at 0x7fa6186a1240>,
#    <pykat.node_network.Node at 0x7fa6186a1710>,
#    <pykat.node_network.Node at 0x7fa6184c4f98>),
#   917: (<pykat.node_network.Node at 0x7fa6186a1710>,
#    <pykat.node_network.Node at 0x7fa6184c4e10>),
#   918: (<pykat.node_network.Node at 0x7fa6184c4f98>,
#    <pykat.node_network.Node at 0x7fa6186a1d30>),
#   919: (<pykat.node_network.Node at 0x7fa6184c4e10>,
#    <pykat.node_network.Node at 0x7fa6186a0fd0>,
#    <pykat.node_network.Node at 0x7fa6186a0b00>,
#    <pykat.node_network.Node at 0x7fa6186a1eb8>),
#   920: (<pykat.node_network.Node at 0x7fa6186a1d30>,
#    <pykat.node_network.Node at 0x7fa6186a0080>,
#    <pykat.node_network.Node at 0x7fa6186a00b8>,
#    <pykat.node_network.Node at 0x7fa6186a19e8>),
#   921: (<pykat.node_network.Node at 0x7fa6186a1240>,
#    <pykat.node_network.Node at 0x7fa6184c47f0>),
#   922: (<pykat.node_network.Node at 0x7fa6184c47f0>,
#    <pykat.node_network.Node at 0x7fa6184c4438>),
#   923: (<pykat.node_network.Node at 0x7fa6184c4438>,
#    <pykat.node_network.Node at 0x7fa6186a1668>),
#   924: (<pykat.node_network.Node at 0x7fa6186a1668>,
#    <pykat.node_network.Node at 0x7fa6186a1828>),
#   925: (<pykat.node_network.Node at 0x7fa6186a1828>,
#    <pykat.node_network.Node at 0x7fa6184c4198>),
#   926: (<pykat.node_network.Node at 0x7fa6184c4198>,
#    <pykat.node_network.Node at 0x7fa6184c40f0>),
#   927: (<pykat.node_network.Node at 0x7fa6184c40f0>,
#    <pykat.node_network.Node at 0x7fa6186a05f8>),
#   928: (<pykat.node_network.Node at 0x7fa6186a05f8>,
#    <pykat.node_network.Node at 0x7fa6184c41d0>),
#   929: (<pykat.node_network.Node at 0x7fa6184c41d0>,
#    <pykat.node_network.Node at 0x7fa6184c4320>),
#   930: (<pykat.node_network.Node at 0x7fa6184c4320>,
#    <pykat.node_network.Node at 0x7fa6186a0518>),
#   931: (<pykat.node_network.Node at 0x7fa6186a0518>,
#    <pykat.node_network.Node at 0x7fa6186a1cf8>),
#   932: (<pykat.node_network.Node at 0x7fa6186a1cf8>,
#    <pykat.node_network.Node at 0x7fa6186a1a58>),
#   933: (<pykat.node_network.Node at 0x7fa6186a0b00>,
#    <pykat.node_network.Node at 0x7fa6184c49b0>),
#   934: (<pykat.node_network.Node at 0x7fa6184c49b0>,
#    <pykat.node_network.Node at 0x7fa6186a0978>),
#   935: (<pykat.node_network.Node at 0x7fa6186a0978>,
#    <pykat.node_network.Node at 0x7fa6186a1e48>),
#   936: (<pykat.node_network.Node at 0x7fa6186a1e48>,
#    <pykat.node_network.Node at 0x7fa6186a1c18>),
#   937: (<pykat.node_network.Node at 0x7fa6186a1c18>,
#    <pykat.node_network.Node at 0x7fa6186a1630>),
#   938: (<pykat.node_network.Node at 0x7fa6186a1630>,
#    <pykat.node_network.Node at 0x7fa6184c4518>),
#   939: (<pykat.node_network.Node at 0x7fa6184c4518>,
#    <pykat.node_network.Node at 0x7fa6184c4630>),
#   940: (<pykat.node_network.Node at 0x7fa6184c4630>,
#    <pykat.node_network.Node at 0x7fa6184c4390>),
#   941: (<pykat.node_network.Node at 0x7fa6184c4390>,
#    <pykat.node_network.Node at 0x7fa6184c4a58>),
#   942: (<pykat.node_network.Node at 0x7fa6184c4a58>,
#    <pykat.node_network.Node at 0x7fa6186a1080>),
#   943: (<pykat.node_network.Node at 0x7fa6186a1080>,
#    <pykat.node_network.Node at 0x7fa6186a0f60>),
#   944: (<pykat.node_network.Node at 0x7fa6186a0f60>,
#    <pykat.node_network.Node at 0x7fa6186a18d0>),
#   945: (<pykat.node_network.Node at 0x7fa6186a00b8>,
#    <pykat.node_network.Node at 0x7fa6184c4e80>),
#   946: (<pykat.node_network.Node at 0x7fa6184c4e80>,
#    <pykat.node_network.Node at 0x7fa6184c4588>,
#    <pykat.node_network.Node at 0x7fa6184c47b8>,
#    <pykat.node_network.Node at 0x7fa6186a1390>),
#   947: (<pykat.node_network.Node at 0x7fa6184c4588>,
#    <pykat.node_network.Node at 0x7fa6186a1278>),
#   948: (<pykat.node_network.Node at 0x7fa6186a1278>,
#    <pykat.node_network.Node at 0x7fa6186a04a8>,
#    <pykat.node_network.Node at 0x7fa6184c4c50>,
#    <pykat.node_network.Node at 0x7fa6184c4710>),
#   949: (<pykat.node_network.Node at 0x7fa6186a04a8>,
#    <pykat.node_network.Node at 0x7fa6186a0f28>),
#   950: (<pykat.node_network.Node at 0x7fa6186a0f28>,
#    <pykat.node_network.Node at 0x7fa6186a1ef0>),
#   951: (<pykat.node_network.Node at 0x7fa6186a1ef0>,
#    <pykat.node_network.Node at 0x7fa6186a02e8>),
#   952: (<pykat.node_network.Node at 0x7fa6186a02e8>,
#    <pykat.node_network.Node at 0x7fa6186a1ba8>),
#   953: (<pykat.node_network.Node at 0x7fa6186a1ba8>,
#    <pykat.node_network.Node at 0x7fa6186a1470>),
#   954: (<pykat.node_network.Node at 0x7fa6186a1470>,
#    <pykat.node_network.Node at 0x7fa6186a1128>),
#   955: (<pykat.node_network.Node at 0x7fa6186a1128>,
#    <pykat.node_network.Node at 0x7fa6184c4748>),
#   956: (<pykat.node_network.Node at 0x7fa6184c4748>,
#    <pykat.node_network.Node at 0x7fa6186a1748>,
#    <pykat.node_network.Node at 0x7fa6186a0c88>,
#    <pykat.node_network.Node at 0x7fa6184c4898>),
#   957: (<pykat.node_network.Node at 0x7fa6186a0c88>,
#    <pykat.node_network.Node at 0x7fa6186a1550>),
#   958: (<pykat.node_network.Node at 0x7fa6186a1550>,
#    <pykat.node_network.Node at 0x7fa6184c4be0>),
#   959: (<pykat.node_network.Node at 0x7fa6184c4be0>,
#    <pykat.node_network.Node at 0x7fa6184c4da0>),
#   960: (<pykat.node_network.Node at 0x7fa6184c4da0>,
#    <pykat.node_network.Node at 0x7fa6184c4b70>),
#   961: (<pykat.node_network.Node at 0x7fa6184c4b70>,
#    <pykat.node_network.Node at 0x7fa6184c4048>),
#   962: (<pykat.node_network.Node at 0x7fa6186a10b8>,
#    <pykat.node_network.Node at 0x7fa6184c4048>,
#    <pykat.node_network.Node at 0x7fa6186a1198>),
#   963: (<pykat.node_network.Node at 0x7fa6186a1198>,
#    <pykat.node_network.Node at 0x7fa6186a17f0>),
#   964: (<pykat.node_network.Node at 0x7fa6186a17f0>,
#    <pykat.node_network.Node at 0x7fa6186a0940>),
#   965: (<pykat.node_network.Node at 0x7fa6186a10b8>,
#    <pykat.node_network.Node at 0x7fa6186a1e10>),
#   966: (<pykat.node_network.Node at 0x7fa6186a1e10>,
#    <pykat.node_network.Node at 0x7fa6186a0f98>),
#   967: (<pykat.node_network.Node at 0x7fa6186a0f98>,
#    <pykat.node_network.Node at 0x7fa6186a1e80>),
#   968: (<pykat.node_network.Node at 0x7fa6186a1e80>,
#    <pykat.node_network.Node at 0x7fa6184c4160>),
#   969: (<pykat.node_network.Node at 0x7fa6184c4160>,
#    <pykat.node_network.Node at 0x7fa6184c4b00>),
#   970: (<pykat.node_network.Node at 0x7fa6184c4b00>,
#    <pykat.node_network.Node at 0x7fa6184c4978>),
#   971: (<pykat.node_network.Node at 0x7fa6186a0940>,
#    <pykat.node_network.Node at 0x7fa6186a0898>),
#   972: (<pykat.node_network.Node at 0x7fa6186a0898>,
#    <pykat.node_network.Node at 0x7fa6186a1cc0>),
#   973: (<pykat.node_network.Node at 0x7fa6186a1cc0>,
#    <pykat.node_network.Node at 0x7fa6186a1978>),
#   974: (<pykat.node_network.Node at 0x7fa6186a1978>,
#    <pykat.node_network.Node at 0x7fa6186a16a0>),
#   975: (<pykat.node_network.Node at 0x7fa6186a16a0>,
#    <pykat.node_network.Node at 0x7fa6184c40b8>),
#   976: (<pykat.node_network.Node at 0x7fa6186a0a90>,
#    <pykat.node_network.Node at 0x7fa6184c40b8>,
#    <pykat.node_network.Node at 0x7fa6186a08d0>,
#    <pykat.node_network.Node at 0x7fa6186a1438>),
#   977: (<pykat.node_network.Node at 0x7fa6186a08d0>,
#    <pykat.node_network.Node at 0x7fa6186a10f0>),
#   978: (<pykat.node_network.Node at 0x7fa6184c46a0>,
#    <pykat.node_network.Node at 0x7fa6186a1438>),
#   979: (<pykat.node_network.Node at 0x7fa6186a10f0>,
#    <pykat.node_network.Node at 0x7fa6184c46a0>,
#    <pykat.node_network.Node at 0x7fa6186a16d8>,
#    <pykat.node_network.Node at 0x7fa6184c4c88>),
#   980: (<pykat.node_network.Node at 0x7fa6186a1358>,
#    <pykat.node_network.Node at 0x7fa6186a0a90>),
#   981: (<pykat.node_network.Node at 0x7fa6184c4978>,
#    <pykat.node_network.Node at 0x7fa6186a0da0>),
#   982: (<pykat.node_network.Node at 0x7fa6186a0da0>,
#    <pykat.node_network.Node at 0x7fa6186a02b0>,
#    <pykat.node_network.Node at 0x7fa6184c4080>,
#    <pykat.node_network.Node at 0x7fa6186a0eb8>),
#   983: (<pykat.node_network.Node at 0x7fa6186a02b0>,
#    <pykat.node_network.Node at 0x7fa6184c4550>),
#   984: (<pykat.node_network.Node at 0x7fa6184c4550>,
#    <pykat.node_network.Node at 0x7fa6186a0ba8>,
#    <pykat.node_network.Node at 0x7fa6184c43c8>,
#    <pykat.node_network.Node at 0x7fa6186a1b00>),
#   985: (<pykat.node_network.Node at 0x7fa6186a0ba8>,
#    <pykat.node_network.Node at 0x7fa6184c4470>),
#   986: (<pykat.node_network.Node at 0x7fa6184c4470>,
#    <pykat.node_network.Node at 0x7fa6184c4c18>,
#    <pykat.node_network.Node at 0x7fa6186a1f98>,
#    <pykat.node_network.Node at 0x7fa6184c4eb8>),
#   987: (<pykat.node_network.Node at 0x7fa6184c4c18>,
#    <pykat.node_network.Node at 0x7fa6184c4d68>),
#   988: (<pykat.node_network.Node at 0x7fa6186a1f98>,
#    <pykat.node_network.Node at 0x7fa6186a1518>),
#   989: (<pykat.node_network.Node at 0x7fa6184c4d68>,
#    <pykat.node_network.Node at 0x7fa6186a1208>,
#    <pykat.node_network.Node at 0x7fa6186a0cf8>,
#    <pykat.node_network.Node at 0x7fa6184c4e48>),
#   990: (<pykat.node_network.Node at 0x7fa6186a0cf8>,
#    <pykat.node_network.Node at 0x7fa6184c4240>),
#   991: (<pykat.node_network.Node at 0x7fa6184c4240>,
#    <pykat.node_network.Node at 0x7fa6184c49e8>,
#    <pykat.node_network.Node at 0x7fa6186a0d30>,
#    <pykat.node_network.Node at 0x7fa6184c4908>),
#   992: (<pykat.node_network.Node at 0x7fa6186a0d30>,
#    <pykat.node_network.Node at 0x7fa6186a12b0>),
#   993: (<pykat.node_network.Node at 0x7fa6186a12b0>,
#    <pykat.node_network.Node at 0x7fa6186a0828>,
#    <pykat.node_network.Node at 0x7fa6186a15f8>,
#    <pykat.node_network.Node at 0x7fa6186a13c8>),
#   994: (<pykat.node_network.Node at 0x7fa6186a15f8>,
#    <pykat.node_network.Node at 0x7fa6184c4b38>),
#   995: (<pykat.node_network.Node at 0x7fa6184c4b38>,
#    <pykat.node_network.Node at 0x7fa6184c48d0>,
#    <pykat.node_network.Node at 0x7fa6186a05c0>,
#    <pykat.node_network.Node at 0x7fa6186a1940>),
#   996: (<pykat.node_network.Node at 0x7fa6186a0828>,
#    <pykat.node_network.Node at 0x7fa6184c4cc0>),
#   997: (<pykat.node_network.Node at 0x7fa6184c4cc0>,
#    <pykat.node_network.Node at 0x7fa6186a11d0>,
#    <pykat.node_network.Node at 0x7fa6184c4278>,
#    <pykat.node_network.Node at 0x7fa6184c4828>),
#   998: (<pykat.node_network.Node at 0x7fa6186a11d0>,
#    <pykat.node_network.Node at 0x7fa6186a1908>),
#   999: (<pykat.node_network.Node at 0x7fa6186a1908>,
#    <pykat.node_network.Node at 0x7fa6186a0ef0>,
#    <pykat.node_network.Node at 0x7fa6186a15c0>,
#    <pykat.node_network.Node at 0x7fa6186a17b8>),
#   1000: (<pykat.node_network.Node at 0x7fa6186a0ef0>,
#    <pykat.node_network.Node at 0x7fa6184c4908>)},
#  '_NodeNetwork__kat': <pykat.finesse.kat_16 at 0x7fa61809de48>,
#  '_NodeNetwork__nodeComponents': {1: (<pykat.components.pykat.components.laser_1916 at 0x7fa6180b8550>,
#    <pykat.components.pykat.components.space_1948 at 0x7fa618677d68>),
#   2: (<pykat.components.pykat.components.space_1948 at 0x7fa618677d68>,
#    <pykat.components.pykat.components.modulator_1913 at 0x7fa6186accf8>),
#   3: (<pykat.components.pykat.components.modulator_1913 at 0x7fa6186accf8>,
#    <pykat.components.pykat.components.space_1998 at 0x7fa611427668>),
#   4: (<pykat.components.pykat.components.space_1998 at 0x7fa611427668>,
#    <pykat.components.pykat.components.modulator_2000 at 0x7fa6186a0630>),
#   5: (<pykat.components.pykat.components.modulator_2000 at 0x7fa6186a0630>,
#    <pykat.components.pykat.components.space_1895 at 0x7fa6186cb7f0>),
#   6: (<pykat.components.pykat.components.space_1895 at 0x7fa6186cb7f0>,
#    <pykat.components.pykat.components.modulator_1954 at 0x7fa6180a1f98>),
#   7: (<pykat.components.pykat.components.modulator_1954 at 0x7fa6180a1f98>,
#    <pykat.components.pykat.components.space_1966 at 0x7fa61145c908>),
#   8: (<pykat.components.pykat.components.space_1966 at 0x7fa61145c908>,
#    <pykat.components.pykat.components.beamSplitter_1959 at 0x7fa61142f390>),
#   9: (<pykat.components.pykat.components.beamSplitter_1959 at 0x7fa61142f390>,
#    None),
#   10: (<pykat.components.pykat.components.beamSplitter_1959 at 0x7fa61142f390>,
#    <pykat.components.pykat.components.space_1957 at 0x7fa61142f9b0>),
#   11: (<pykat.components.pykat.components.beamSplitter_1959 at 0x7fa61142f390>,
#    <pykat.components.pykat.components.space_1992 at 0x7fa6183b5ef0>),
#   12: (<pykat.components.pykat.components.space_1957 at 0x7fa61142f9b0>,
#    <pykat.components.pykat.components.beamSplitter_1971 at 0x7fa6180afda0>),
#   13: (<pykat.components.pykat.components.beamSplitter_1971 at 0x7fa6180afda0>,
#    <pykat.components.pykat.components.space_1958 at 0x7fa61142ff60>),
#   14: (<pykat.components.pykat.components.beamSplitter_1971 at 0x7fa6180afda0>,
#    None),
#   16: (<pykat.components.pykat.components.space_1958 at 0x7fa61142ff60>,
#    <pykat.components.pykat.components.beamSplitter_1963 at 0x7fa611425860>),
#   17: (<pykat.components.pykat.components.beamSplitter_1963 at 0x7fa611425860>,
#    <pykat.components.pykat.components.space_1992 at 0x7fa6183b5ef0>),
#   18: (<pykat.components.pykat.components.beamSplitter_1963 at 0x7fa611425860>,
#    <pykat.components.pykat.components.space_1903 at 0x7fa6186d5e80>),
#   19: (<pykat.components.pykat.components.beamSplitter_1963 at 0x7fa611425860>,
#    None),
#   20: (<pykat.components.pykat.components.space_1903 at 0x7fa6186d5e80>,
#    <pykat.components.pykat.components.beamSplitter_1981 at 0x7fa61144aac8>),
#   22: (<pykat.components.pykat.components.beamSplitter_1981 at 0x7fa61144aac8>,
#    <pykat.components.pykat.components.space_1889 at 0x7fa6186d3c18>),
#   24: (<pykat.components.pykat.components.space_1889 at 0x7fa6186d3c18>,
#    <pykat.components.pykat.components.beamSplitter_1970 at 0x7fa619052e48>),
#   25: (<pykat.components.pykat.components.beamSplitter_1970 at 0x7fa619052e48>,
#    <pykat.components.pykat.components.space_1896 at 0x7fa6186cb9b0>),
#   26: (<pykat.components.pykat.components.beamSplitter_1970 at 0x7fa619052e48>,
#    <pykat.components.pykat.components.space_1990 at 0x7fa6183b5dd8>),
#   28: (<pykat.components.pykat.components.space_1990 at 0x7fa6183b5dd8>,
#    <pykat.components.pykat.components.beamSplitter_1960 at 0x7fa6183e8d30>),
#   30: (<pykat.components.pykat.components.beamSplitter_1960 at 0x7fa6183e8d30>,
#    <pykat.components.pykat.components.space_1884 at 0x7fa618099710>),
#   32: (<pykat.components.pykat.components.space_1884 at 0x7fa618099710>, None),
#   33: (<pykat.components.pykat.components.space_1896 at 0x7fa6186cb9b0>,
#    <pykat.components.pykat.components.lens_1942 at 0x7fa6183c0f98>),
#   34: (<pykat.components.pykat.components.lens_1942 at 0x7fa6183c0f98>,
#    <pykat.components.pykat.components.space_1976 at 0x7fa6186b58d0>),
#   35: (<pykat.components.pykat.components.space_1976 at 0x7fa6186b58d0>,
#    <pykat.components.pykat.components.beamSplitter_1962 at 0x7fa6114251d0>),
#   36: (<pykat.components.pykat.components.beamSplitter_1962 at 0x7fa6114251d0>,
#    <pykat.components.pykat.components.space_1908 at 0x7fa6186c0208>),
#   39: (<pykat.components.pykat.components.space_1908 at 0x7fa6186c0208>,
#    <pykat.components.pykat.components.beamSplitter_1904 at 0x7fa6186d5780>),
#   40: (<pykat.components.pykat.components.beamSplitter_1904 at 0x7fa6186d5780>,
#    <pykat.components.pykat.components.space_1994 at 0x7fa6183b5be0>),
#   43: (<pykat.components.pykat.components.space_1994 at 0x7fa6183b5be0>,
#    <pykat.components.pykat.components.lens_1891 at 0x7fa6186cb0b8>),
#   44: (<pykat.components.pykat.components.lens_1891 at 0x7fa6186cb0b8>,
#    <pykat.components.pykat.components.space_1922 at 0x7fa6180ddeb8>),
#   45: (<pykat.components.pykat.components.space_1922 at 0x7fa6180ddeb8>,
#    <pykat.components.pykat.components.beamSplitter_1956 at 0x7fa611439438>),
#   46: (<pykat.components.pykat.components.beamSplitter_1956 at 0x7fa611439438>,
#    <pykat.components.pykat.components.space_1953 at 0x7fa6114394e0>),
#   47: (<pykat.components.pykat.components.beamSplitter_1956 at 0x7fa611439438>,
#    None),
#   48: (<pykat.components.pykat.components.beamSplitter_1956 at 0x7fa611439438>,
#    None),
#   49: (<pykat.components.pykat.components.space_1953 at 0x7fa6114394e0>,
#    <pykat.components.pykat.components.mirror_1892 at 0x7fa6186cbcc0>),
#   50: (<pykat.components.pykat.components.mirror_1892 at 0x7fa6186cbcc0>,
#    <pykat.components.pykat.components.space_1952 at 0x7fa6114396d8>),
#   51: (<pykat.components.pykat.components.space_1952 at 0x7fa6114396d8>,
#    <pykat.components.pykat.components.mirror_1989 at 0x7fa618426a20>),
#   52: (<pykat.components.pykat.components.mirror_1989 at 0x7fa618426a20>,
#    <pykat.components.pykat.components.space_1939 at 0x7fa618088c50>),
#   53: (<pykat.components.pykat.components.space_1939 at 0x7fa618088c50>,
#    <pykat.components.pykat.components.beamSplitter_1936 at 0x7fa6180e5518>),
#   54: (<pykat.components.pykat.components.beamSplitter_1936 at 0x7fa6180e5518>,
#    <pykat.components.pykat.components.space_1985 at 0x7fa6184265c0>),
#   55: (<pykat.components.pykat.components.beamSplitter_1936 at 0x7fa6180e5518>,
#    None),
#   57: (<pykat.components.pykat.components.space_1985 at 0x7fa6184265c0>,
#    <pykat.components.pykat.components.beamSplitter_1898 at 0x7fa6186ba2e8>),
#   58: (<pykat.components.pykat.components.beamSplitter_1898 at 0x7fa6186ba2e8>,
#    <pykat.components.pykat.components.space_1883 at 0x7fa6186d0b00>),
#   61: (<pykat.components.pykat.components.space_1883 at 0x7fa6186d0b00>,
#    <pykat.components.pykat.components.beamSplitter_1944 at 0x7fa6186770f0>),
#   62: (<pykat.components.pykat.components.beamSplitter_1944 at 0x7fa6186770f0>,
#    <pykat.components.pykat.components.space_1961 at 0x7fa611425320>),
#   63: (<pykat.components.pykat.components.beamSplitter_1944 at 0x7fa6186770f0>,
#    <pykat.components.pykat.components.space_1890 at 0x7fa6186d33c8>),
#   64: (<pykat.components.pykat.components.beamSplitter_1944 at 0x7fa6186770f0>,
#    <pykat.components.pykat.components.space_1876 at 0x7fa61868eda0>),
#   65: (<pykat.components.pykat.components.space_1890 at 0x7fa6186d33c8>,
#    <pykat.components.pykat.components.beamSplitter_1907 at 0x7fa6186c0898>),
#   66: (<pykat.components.pykat.components.space_1876 at 0x7fa61868eda0>,
#    <pykat.components.pykat.components.beamSplitter_1933 at 0x7fa6183cce80>),
#   68: (<pykat.components.pykat.components.beamSplitter_1907 at 0x7fa6186c0898>,
#    <pykat.components.pykat.components.space_1967 at 0x7fa61145ccc0>),
#   69: (<pykat.components.pykat.components.beamSplitter_1907 at 0x7fa6186c0898>,
#    None),
#   71: (<pykat.components.pykat.components.beamSplitter_1933 at 0x7fa6183cce80>,
#    <pykat.components.pykat.components.space_1984 at 0x7fa618426940>),
#   73: (<pykat.components.pykat.components.space_1961 at 0x7fa611425320>,
#    <pykat.components.pykat.components.lens_1978 at 0x7fa6191574e0>),
#   74: (<pykat.components.pykat.components.lens_1978 at 0x7fa6191574e0>,
#    <pykat.components.pykat.components.space_1940 at 0x7fa618088e10>),
#   75: (<pykat.components.pykat.components.space_1940 at 0x7fa618088e10>,
#    <pykat.components.pykat.components.lens_1894 at 0x7fa6186cbcf8>),
#   76: (<pykat.components.pykat.components.lens_1894 at 0x7fa6186cbcf8>,
#    <pykat.components.pykat.components.space_1988 at 0x7fa618426cc0>),
#   77: (<pykat.components.pykat.components.space_1988 at 0x7fa618426cc0>,
#    <pykat.components.pykat.components.mirror_1950 at 0x7fa6180a1048>),
#   78: (<pykat.components.pykat.components.mirror_1950 at 0x7fa6180a1048>,
#    <pykat.components.pykat.components.space_1977 at 0x7fa6186b5588>),
#   79: (<pykat.components.pykat.components.space_1977 at 0x7fa6186b5588>,
#    <pykat.components.pykat.components.mirror_1941 at 0x7fa6183c0128>),
#   80: (<pykat.components.pykat.components.mirror_1941 at 0x7fa6183c0128>,
#    <pykat.components.pykat.components.space_1877 at 0x7fa619157eb8>),
#   81: (<pykat.components.pykat.components.space_1877 at 0x7fa619157eb8>,
#    <pykat.components.pykat.components.mirror_1964 at 0x7fa61145c9b0>),
#   82: (<pykat.components.pykat.components.mirror_1964 at 0x7fa61145c9b0>,
#    <pykat.components.pykat.components.space_1879 at 0x7fa6180da0f0>),
#   83: (<pykat.components.pykat.components.space_1879 at 0x7fa6180da0f0>,
#    <pykat.components.pykat.components.mirror_1972 at 0x7fa6183bbdd8>),
#   84: (<pykat.components.pykat.components.mirror_1972 at 0x7fa6183bbdd8>,
#    None),
#   85: (<pykat.components.pykat.components.space_1967 at 0x7fa61145ccc0>,
#    <pykat.components.pykat.components.lens_1900 at 0x7fa6186ba550>),
#   86: (<pykat.components.pykat.components.lens_1900 at 0x7fa6186ba550>,
#    <pykat.components.pykat.components.space_1901 at 0x7fa6186d5be0>),
#   87: (<pykat.components.pykat.components.space_1901 at 0x7fa6186d5be0>,
#    <pykat.components.pykat.components.lens_1997 at 0x7fa618099d30>),
#   88: (<pykat.components.pykat.components.lens_1997 at 0x7fa618099d30>,
#    <pykat.components.pykat.components.space_1888 at 0x7fa6186d3470>),
#   89: (<pykat.components.pykat.components.space_1888 at 0x7fa6186d3470>,
#    <pykat.components.pykat.components.mirror_1999 at 0x7fa611427390>),
#   90: (<pykat.components.pykat.components.mirror_1999 at 0x7fa611427390>,
#    <pykat.components.pykat.components.space_1937 at 0x7fa6184207b8>),
#   91: (<pykat.components.pykat.components.space_1937 at 0x7fa6184207b8>,
#    <pykat.components.pykat.components.mirror_1979 at 0x7fa6186b5a20>),
#   92: (<pykat.components.pykat.components.mirror_1979 at 0x7fa6186b5a20>,
#    <pykat.components.pykat.components.space_1902 at 0x7fa6186d5eb8>),
#   93: (<pykat.components.pykat.components.space_1902 at 0x7fa6186d5eb8>,
#    <pykat.components.pykat.components.mirror_1923 at 0x7fa6186822e8>),
#   94: (<pykat.components.pykat.components.mirror_1923 at 0x7fa6186822e8>,
#    <pykat.components.pykat.components.space_1919 at 0x7fa6186862b0>),
#   95: (<pykat.components.pykat.components.space_1919 at 0x7fa6186862b0>,
#    <pykat.components.pykat.components.mirror_1996 at 0x7fa611427e80>),
#   96: (<pykat.components.pykat.components.mirror_1996 at 0x7fa611427e80>,
#    None),
#   97: (<pykat.components.pykat.components.space_1984 at 0x7fa618426940>,
#    <pykat.components.pykat.components.beamSplitter_1928 at 0x7fa612d160f0>),
#   98: (<pykat.components.pykat.components.beamSplitter_1928 at 0x7fa612d160f0>,
#    <pykat.components.pykat.components.space_1914 at 0x7fa6186ac5c0>),
#   101: (<pykat.components.pykat.components.space_1914 at 0x7fa6186ac5c0>,
#    <pykat.components.pykat.components.beamSplitter_1931 at 0x7fa618090dd8>),
#   102: (<pykat.components.pykat.components.beamSplitter_1931 at 0x7fa618090dd8>,
#    <pykat.components.pykat.components.space_1930 at 0x7fa6184e0d68>),
#   105: (<pykat.components.pykat.components.space_1930 at 0x7fa6184e0d68>,
#    <pykat.components.pykat.components.mirror_1880 at 0x7fa61868ee10>),
#   106: (<pykat.components.pykat.components.mirror_1880 at 0x7fa61868ee10>,
#    <pykat.components.pykat.components.space_1915 at 0x7fa6186ac358>),
#   107: (<pykat.components.pykat.components.space_1915 at 0x7fa6186ac358>,
#    <pykat.components.pykat.components.mirror_1982 at 0x7fa61144a668>),
#   108: (<pykat.components.pykat.components.mirror_1982 at 0x7fa61144a668>,
#    <pykat.components.pykat.components.space_1934 at 0x7fa61915d0f0>),
#   109: (<pykat.components.pykat.components.space_1934 at 0x7fa61915d0f0>,
#    <pykat.components.pykat.components.mirror_1991 at 0x7fa6183b5f98>),
#   110: (<pykat.components.pykat.components.mirror_1991 at 0x7fa6183b5f98>,
#    <pykat.components.pykat.components.space_1906 at 0x7fa6186c0160>),
#   111: (<pykat.components.pykat.components.space_1906 at 0x7fa6186c0160>,
#    <pykat.components.pykat.components.beamSplitter_1974 at 0x7fa6183bb7b8>),
#   113: (<pykat.components.pykat.components.beamSplitter_1974 at 0x7fa6183bb7b8>,
#    <pykat.components.pykat.components.space_1980 at 0x7fa61144ab00>),
#   115: (<pykat.components.pykat.components.space_1980 at 0x7fa61144ab00>,
#    <pykat.components.pykat.components.mirror_1905 at 0x7fa618090748>),
#   116: (<pykat.components.pykat.components.mirror_1905 at 0x7fa618090748>,
#    <pykat.components.pykat.components.space_1927 at 0x7fa618684080>),
#   117: (<pykat.components.pykat.components.space_1927 at 0x7fa618684080>,
#    <pykat.components.pykat.components.mirror_1926 at 0x7fa61809df28>),
#   118: (<pykat.components.pykat.components.mirror_1926 at 0x7fa61809df28>,
#    <pykat.components.pykat.components.space_1921 at 0x7fa618686d68>),
#   119: (<pykat.components.pykat.components.space_1921 at 0x7fa618686d68>,
#    <pykat.components.pykat.components.isolator_1881 at 0x7fa618099048>),
#   120: (<pykat.components.pykat.components.isolator_1881 at 0x7fa618099048>,
#    <pykat.components.pykat.components.space_1932 at 0x7fa6183cc7b8>),
#   121: (<pykat.components.pykat.components.isolator_1881 at 0x7fa618099048>,
#    <pykat.components.pykat.components.space_1929 at 0x7fa6184784e0>),
#   122: (<pykat.components.pykat.components.space_1929 at 0x7fa6184784e0>,
#    <pykat.components.pykat.components.mirror_1885 at 0x7fa6186d0e48>),
#   123: (<pykat.components.pykat.components.mirror_1885 at 0x7fa6186d0e48>,
#    <pykat.components.pykat.components.space_1909 at 0x7fa6180a1198>),
#   124: (<pykat.components.pykat.components.space_1932 at 0x7fa6183cc7b8>,
#    <pykat.components.pykat.components.mirror_1917 at 0x7fa6180fb198>),
#   125: (<pykat.components.pykat.components.mirror_1917 at 0x7fa6180fb198>,
#    <pykat.components.pykat.components.space_1968 at 0x7fa618099dd8>),
#   126: (<pykat.components.pykat.components.space_1968 at 0x7fa618099dd8>,
#    <pykat.components.pykat.components.mirror_1887 at 0x7fa6186d3780>),
#   127: (<pykat.components.pykat.components.mirror_1887 at 0x7fa6186d3780>,
#    <pykat.components.pykat.components.space_1993 at 0x7fa6183b5470>),
#   128: (<pykat.components.pykat.components.space_1993 at 0x7fa6183b5470>,
#    <pykat.components.pykat.components.mirror_1955 at 0x7fa611439748>),
#   129: (<pykat.components.pykat.components.mirror_1955 at 0x7fa611439748>,
#    <pykat.components.pykat.components.space_1986 at 0x7fa618426780>),
#   130: (<pykat.components.pykat.components.space_1909 at 0x7fa6180a1198>,
#    <pykat.components.pykat.components.lens_1949 at 0x7fa618677fd0>),
#   131: (<pykat.components.pykat.components.lens_1949 at 0x7fa618677fd0>,
#    <pykat.components.pykat.components.space_1918 at 0x7fa618686588>),
#   132: (<pykat.components.pykat.components.space_1918 at 0x7fa618686588>,
#    <pykat.components.pykat.components.lens_1910 at 0x7fa618090e48>),
#   133: (<pykat.components.pykat.components.lens_1910 at 0x7fa618090e48>,
#    <pykat.components.pykat.components.space_1878 at 0x7fa61868e208>),
#   134: (<pykat.components.pykat.components.space_1878 at 0x7fa61868e208>,
#    <pykat.components.pykat.components.beamSplitter_1882 at 0x7fa6186d0390>),
#   135: (<pykat.components.pykat.components.beamSplitter_1882 at 0x7fa6186d0390>,
#    <pykat.components.pykat.components.space_1946 at 0x7fa618677128>),
#   136: (<pykat.components.pykat.components.beamSplitter_1882 at 0x7fa6186d0390>,
#    <pykat.components.pykat.components.space_1897 at 0x7fa6186cbb38>),
#   137: (<pykat.components.pykat.components.beamSplitter_1882 at 0x7fa6186d0390>,
#    <pykat.components.pykat.components.space_1973 at 0x7fa6183bb470>),
#   138: (<pykat.components.pykat.components.space_1897 at 0x7fa6186cbb38>,
#    <pykat.components.pykat.components.beamSplitter_1969 at 0x7fa619052128>),
#   139: (<pykat.components.pykat.components.space_1973 at 0x7fa6183bb470>,
# ...
#   'nMC2refl': <pykat.node_network.Node at 0x7fa6186a1ac8>,
#   'nMC2trans': <pykat.node_network.Node at 0x7fa6186a0668>,
#   'nMC3ARin': <pykat.node_network.Node at 0x7fa6184c44e0>,
#   'nMC3ARtrans': <pykat.node_network.Node at 0x7fa6186a0198>,
#   'nMC3in': <pykat.node_network.Node at 0x7fa6186a04e0>,
#   'nMC3refl': <pykat.node_network.Node at 0x7fa6184c4f60>,
#   'nMC3trans': <pykat.node_network.Node at 0x7fa6186a09e8>,
#   'nMCreturn_refl': <pykat.node_network.Node at 0x7fa6184c4a90>,
#   'nOBAin': <pykat.node_network.Node at 0x7fa6184c4b00>,
#   'nOBAout': <pykat.node_network.Node at 0x7fa6184c4978>,
#   'nOFIin': <pykat.node_network.Node at 0x7fa6184c4748>,
#   'nOFIout': <pykat.node_network.Node at 0x7fa6186a0f98>,
#   'nOFIout2': <pykat.node_network.Node at 0x7fa6186a0940>,
#   'nOM1a': <pykat.node_network.Node at 0x7fa6186a0da0>,
#   'nOM1b': <pykat.node_network.Node at 0x7fa6186a02b0>,
#   'nOM2a': <pykat.node_network.Node at 0x7fa6184c4550>,
#   'nOM2b': <pykat.node_network.Node at 0x7fa6186a0ba8>,
#   'nOM3a': <pykat.node_network.Node at 0x7fa6184c4470>,
#   'nOM3b': <pykat.node_network.Node at 0x7fa6184c4c18>,
#   'nOM3trans': <pykat.node_network.Node at 0x7fa6186a1f98>,
#   'nOMC_ARIC2_in': <pykat.node_network.Node at 0x7fa6186a1518>,
#   'nOMC_ARIC_in': <pykat.node_network.Node at 0x7fa6184c4d68>,
#   'nOMC_ARIC_trans': <pykat.node_network.Node at 0x7fa6186a0cf8>,
#   'nOMC_AROC_in': <pykat.node_network.Node at 0x7fa6184c4b38>,
#   'nOMC_AROC_trans': <pykat.node_network.Node at 0x7fa6186a05c0>,
#   'nOMC_CM1_in': <pykat.node_network.Node at 0x7fa6184c4cc0>,
#   'nOMC_CM1_refl': <pykat.node_network.Node at 0x7fa6186a11d0>,
#   'nOMC_CM2_in': <pykat.node_network.Node at 0x7fa6186a1908>,
#   'nOMC_CM2_refl': <pykat.node_network.Node at 0x7fa6186a0ef0>,
#   'nOMC_HRIC_in': <pykat.node_network.Node at 0x7fa6184c4240>,
#   'nOMC_HRIC_trans': <pykat.node_network.Node at 0x7fa6186a0d30>,
#   'nOMC_HRICret': <pykat.node_network.Node at 0x7fa6184c4908>,
#   'nOMC_HROC_in': <pykat.node_network.Node at 0x7fa6186a12b0>,
#   'nOMC_HROC_refl': <pykat.node_network.Node at 0x7fa6186a0828>,
#   'nOMC_HROC_ret': <pykat.node_network.Node at 0x7fa6186a13c8>,
#   'nOMC_HROC_trans': <pykat.node_network.Node at 0x7fa6186a15f8>,
#   'nOPa': <pykat.node_network.Node at 0x7fa6184c4b70>,
#   'nOPb': <pykat.node_network.Node at 0x7fa6184c4048>,
#   'nOPc': <pykat.node_network.Node at 0x7fa6186a1198>,
#   'nOPd': <pykat.node_network.Node at 0x7fa6186a10b8>,
#   'nOPe': <pykat.node_network.Node at 0x7fa6186a17f0>,
#   'nOPf': <pykat.node_network.Node at 0x7fa6186a1e10>,
#   'nPOP': <pykat.node_network.Node at 0x7fa6186a1b38>,
#   'nPOX': <pykat.node_network.Node at 0x7fa6186a1eb8>,
#   'nPR2a': <pykat.node_network.Node at 0x7fa6186a0400>,
#   'nPR2b': <pykat.node_network.Node at 0x7fa6184c4dd8>,
#   'nPR3a': <pykat.node_network.Node at 0x7fa6184c45c0>,
#   'nPR3b': <pykat.node_network.Node at 0x7fa6184c4fd0>,
#   'nPRBS': <pykat.node_network.Node at 0x7fa6184c4668>,
#   'nPRMARb': <pykat.node_network.Node at 0x7fa6184c45f8>,
#   'nPRMHRa': <pykat.node_network.Node at 0x7fa6186a19b0>,
#   'nPRMHRb': <pykat.node_network.Node at 0x7fa6186a0780>,
#   'nPTX': <pykat.node_network.Node at 0x7fa6186a18d0>,
#   'nPTY': <pykat.node_network.Node at 0x7fa6186a1a58>,
#   'nREFL': <pykat.node_network.Node at 0x7fa6186a1fd0>,
#   'nROTb': <pykat.node_network.Node at 0x7fa6184c4be0>,
#   'nROTin': <pykat.node_network.Node at 0x7fa6186a1550>,
#   'nROTouta': <pykat.node_network.Node at 0x7fa6184c4da0>,
#   'nSR2a': <pykat.node_network.Node at 0x7fa6186a04a8>,
#   'nSR2b': <pykat.node_network.Node at 0x7fa6186a1278>,
#   'nSR3a': <pykat.node_network.Node at 0x7fa6184c4588>,
#   'nSR3b': <pykat.node_network.Node at 0x7fa6184c4e80>,
#   'nSRBS': <pykat.node_network.Node at 0x7fa6186a00b8>,
#   'nSRMARa': <pykat.node_network.Node at 0x7fa6186a02e8>,
#   'nSRMARb': <pykat.node_network.Node at 0x7fa6186a1ba8>,
#   'nSRMHRa': <pykat.node_network.Node at 0x7fa6186a0f28>,
#   'nSRMHRb': <pykat.node_network.Node at 0x7fa6186a1ef0>,
#   'nWPa': <pykat.node_network.Node at 0x7fa6186a1e80>,
#   'nWPb': <pykat.node_network.Node at 0x7fa6184c4160>,
#   'nXBS': <pykat.node_network.Node at 0x7fa6186a0b00>,
#   'nYBS': <pykat.node_network.Node at 0x7fa6186a1240>,
#   'nlensFC1a': <pykat.node_network.Node at 0x7fa6186a0898>,
#   'nlensFC1b': <pykat.node_network.Node at 0x7fa6186a1cc0>,
#   'nlensFC2a': <pykat.node_network.Node at 0x7fa6186a1978>,
#   'nlensFC2b': <pykat.node_network.Node at 0x7fa6186a16a0>,
#   'nsqz': <pykat.node_network.Node at 0x7fa6186a1358>},
#  '__node_dump_0': <pykat.node_network.Node at 0x7fa6186a0860>,
#  '__node_dump_1': <pykat.node_network.Node at 0x7fa6186a0d68>,
#  '__node_dump_10': <pykat.node_network.Node at 0x7fa6186a1390>,
#  '__node_dump_11': <pykat.node_network.Node at 0x7fa6184c4080>,
#  '__node_dump_12': <pykat.node_network.Node at 0x7fa6186a0eb8>,
#  '__node_dump_13': <pykat.node_network.Node at 0x7fa6184c4c50>,
#  '__node_dump_14': <pykat.node_network.Node at 0x7fa6184c4710>,
#  '__node_dump_15': <pykat.node_network.Node at 0x7fa6186a15c0>,
#  '__node_dump_16': <pykat.node_network.Node at 0x7fa6186a17b8>,
#  '__node_dump_17': <pykat.node_network.Node at 0x7fa6184c4ac8>,
#  '__node_dump_18': <pykat.node_network.Node at 0x7fa6184c43c8>,
#  '__node_dump_19': <pykat.node_network.Node at 0x7fa6186a1b00>,
#  '__node_dump_2': <pykat.node_network.Node at 0x7fa6184c48d0>,
#  '__node_dump_20': <pykat.node_network.Node at 0x7fa6184c4278>,
#  '__node_dump_21': <pykat.node_network.Node at 0x7fa6184c4828>,
#  '__node_dump_22': <pykat.node_network.Node at 0x7fa6186a1208>,
#  '__node_dump_23': <pykat.node_network.Node at 0x7fa6184c4e48>,
#  '__node_dump_24': <pykat.node_network.Node at 0x7fa6184c4128>,
#  '__node_dump_25': <pykat.node_network.Node at 0x7fa6186a06a0>,
#  '__node_dump_26': <pykat.node_network.Node at 0x7fa6184c4208>,
#  '__node_dump_27': <pykat.node_network.Node at 0x7fa6186a1a20>,
#  '__node_dump_28': <pykat.node_network.Node at 0x7fa6186a16d8>,
#  '__node_dump_29': <pykat.node_network.Node at 0x7fa6184c4c88>,
#  '__node_dump_3': <pykat.node_network.Node at 0x7fa6186a1940>,
#  '__node_dump_30': <pykat.node_network.Node at 0x7fa6186a1b70>,
#  '__node_dump_31': <pykat.node_network.Node at 0x7fa6186a1748>,
#  '__node_dump_32': <pykat.node_network.Node at 0x7fa6184c4898>,
#  '__node_dump_33': <pykat.node_network.Node at 0x7fa6186a0080>,
#  '__node_dump_34': <pykat.node_network.Node at 0x7fa6186a19e8>,
#  '__node_dump_35': <pykat.node_network.Node at 0x7fa6186a1780>,
#  '__node_dump_36': <pykat.node_network.Node at 0x7fa6186a1400>,
#  '__node_dump_37': <pykat.node_network.Node at 0x7fa6186a1f60>,
#  '__node_dump_4': <pykat.node_network.Node at 0x7fa6186a14e0>,
#  '__node_dump_5': <pykat.node_network.Node at 0x7fa6186a1c88>,
#  '__node_dump_6': <pykat.node_network.Node at 0x7fa6186a0fd0>,
#  '__node_dump_7': <pykat.node_network.Node at 0x7fa6184c4eb8>,
#  '__node_dump_8': <pykat.node_network.Node at 0x7fa6184c49e8>,
#  '__node_dump_9': <pykat.node_network.Node at 0x7fa6184c47b8>,
#  '__node_n0': <pykat.node_network.Node at 0x7fa6186a1c50>,
#  '__node_n1': <pykat.node_network.Node at 0x7fa6184c42b0>,
#  '__node_n2': <pykat.node_network.Node at 0x7fa6184c42e8>,
#  '__node_n3': <pykat.node_network.Node at 0x7fa6184c4cf8>,
#  '__node_n4': <pykat.node_network.Node at 0x7fa6184c4860>,
#  '__node_n5': <pykat.node_network.Node at 0x7fa6186a1860>,
#  '__node_n6': <pykat.node_network.Node at 0x7fa6186a1320>,
#  '__node_nAOE1in': <pykat.node_network.Node at 0x7fa6186a1dd8>,
#  '__node_nAOE1trans': <pykat.node_network.Node at 0x7fa6186a1898>,
#  '__node_nAOE2in': <pykat.node_network.Node at 0x7fa6184c46d8>,
#  '__node_nAOE2trans': <pykat.node_network.Node at 0x7fa6186a01d0>,
#  '__node_nBSi1': <pykat.node_network.Node at 0x7fa6186a1710>,
#  '__node_nBSi2': <pykat.node_network.Node at 0x7fa6184c4e10>,
#  '__node_nBSi3': <pykat.node_network.Node at 0x7fa6184c4f98>,
#  '__node_nBSi4': <pykat.node_network.Node at 0x7fa6186a1d30>,
#  '__node_nEMFC1': <pykat.node_network.Node at 0x7fa6186a10f0>,
#  '__node_nEMFC2': <pykat.node_network.Node at 0x7fa6184c46a0>,
#  '__node_nETMX1': <pykat.node_network.Node at 0x7fa6184c4a58>,
#  '__node_nETMXs1': <pykat.node_network.Node at 0x7fa6186a1080>,
#  '__node_nETMXs2': <pykat.node_network.Node at 0x7fa6186a0f60>,
#  '__node_nETMY1': <pykat.node_network.Node at 0x7fa6184c4320>,
#  '__node_nETMYs1': <pykat.node_network.Node at 0x7fa6186a0518>,
#  '__node_nETMYs2': <pykat.node_network.Node at 0x7fa6186a1cf8>,
#  '__node_nIBAin': <pykat.node_network.Node at 0x7fa6186a1470>,
#  '__node_nIBAout': <pykat.node_network.Node at 0x7fa6186a1128>,
#  '__node_nIM1ARin': <pykat.node_network.Node at 0x7fa6186a1da0>,
#  '__node_nIM1ARtrans': <pykat.node_network.Node at 0x7fa6186a1160>,
#  '__node_nIM1HRtrans': <pykat.node_network.Node at 0x7fa6184c4f28>,
#  '__node_nIM1in': <pykat.node_network.Node at 0x7fa6184c4940>,
#  '__node_nIM1refl': <pykat.node_network.Node at 0x7fa6186a0b70>,
#  '__node_nIM2in': <pykat.node_network.Node at 0x7fa6186a1048>,
#  '__node_nIM2refl': <pykat.node_network.Node at 0x7fa6184c4d30>,
#  '__node_nIM3in': <pykat.node_network.Node at 0x7fa6186a06d8>,
#  '__node_nIM3refl': <pykat.node_network.Node at 0x7fa6186a1a90>,
#  '__node_nIM4in': <pykat.node_network.Node at 0x7fa6186a1be0>,
#  '__node_nIM4refl': <pykat.node_network.Node at 0x7fa6186a1f28>,
#  '__node_nIM4rettrans': <pykat.node_network.Node at 0x7fa6186a12e8>,
#  '__node_nIM4trans': <pykat.node_network.Node at 0x7fa6186a1d68>,
#  '__node_nIMFC1': <pykat.node_network.Node at 0x7fa6186a0a90>,
#  '__node_nIMFC2': <pykat.node_network.Node at 0x7fa6184c40b8>,
#  '__node_nIMFC3': <pykat.node_network.Node at 0x7fa6186a08d0>,
#  '__node_nIMFC4': <pykat.node_network.Node at 0x7fa6186a1438>,
#  '__node_nIOT2Lnanoscan': <pykat.node_network.Node at 0x7fa6184c4ef0>,
#  '__node_nIPtrans': <pykat.node_network.Node at 0x7fa6186a0c88>,
#  '__node_nITMX1': <pykat.node_network.Node at 0x7fa6186a1630>,
#  '__node_nITMX11': <pykat.node_network.Node at 0x7fa6184c49b0>,
#  '__node_nITMX2': <pykat.node_network.Node at 0x7fa6184c4390>,
#  '__node_nITMXTLtrans': <pykat.node_network.Node at 0x7fa6186a0978>,
#  '__node_nITMXconstL_in': <pykat.node_network.Node at 0x7fa6186a1e48>,
#  '__node_nITMXconstL_trans': <pykat.node_network.Node at 0x7fa6186a1c18>,
#  '__node_nITMXs1': <pykat.node_network.Node at 0x7fa6184c4518>,
#  '__node_nITMXs2': <pykat.node_network.Node at 0x7fa6184c4630>,
#  '__node_nITMY1': <pykat.node_network.Node at 0x7fa6184c4198>,
#  '__node_nITMY11': <pykat.node_network.Node at 0x7fa6184c47f0>,
#  '__node_nITMY2': <pykat.node_network.Node at 0x7fa6184c41d0>,
#  '__node_nITMYTLtrans': <pykat.node_network.Node at 0x7fa6184c4438>,
#  '__node_nITMYconstL_in': <pykat.node_network.Node at 0x7fa6186a1668>,
#  '__node_nITMYconstL_trans': <pykat.node_network.Node at 0x7fa6186a1828>,
#  '__node_nITMYs1': <pykat.node_network.Node at 0x7fa6184c40f0>,
#  '__node_nITMYs2': <pykat.node_network.Node at 0x7fa6186a05f8>,
#  '__node_nMC1fromMC3': <pykat.node_network.Node at 0x7fa6186a00f0>,
#  '__node_nMC1in': <pykat.node_network.Node at 0x7fa6186a0be0>,
#  '__node_nMC1refl': <pykat.node_network.Node at 0x7fa6186a1588>,
#  '__node_nMC1trans': <pykat.node_network.Node at 0x7fa6184c4780>,
#  '__node_nMC2in': <pykat.node_network.Node at 0x7fa6186a0160>,
#  '__node_nMC2refl': <pykat.node_network.Node at 0x7fa6186a1ac8>,
#  '__node_nMC2trans': <pykat.node_network.Node at 0x7fa6186a0668>,
#  '__node_nMC3ARin': <pykat.node_network.Node at 0x7fa6184c44e0>,
#  '__node_nMC3ARtrans': <pykat.node_network.Node at 0x7fa6186a0198>,
#  '__node_nMC3in': <pykat.node_network.Node at 0x7fa6186a04e0>,
#  '__node_nMC3refl': <pykat.node_network.Node at 0x7fa6184c4f60>,
#  '__node_nMC3trans': <pykat.node_network.Node at 0x7fa6186a09e8>,
#  '__node_nMCreturn_refl': <pykat.node_network.Node at 0x7fa6184c4a90>,
#  '__node_nOBAin': <pykat.node_network.Node at 0x7fa6184c4b00>,
#  '__node_nOBAout': <pykat.node_network.Node at 0x7fa6184c4978>,
#  '__node_nOFIin': <pykat.node_network.Node at 0x7fa6184c4748>,
#  '__node_nOFIout': <pykat.node_network.Node at 0x7fa6186a0f98>,
#  '__node_nOFIout2': <pykat.node_network.Node at 0x7fa6186a0940>,
#  '__node_nOM1a': <pykat.node_network.Node at 0x7fa6186a0da0>,
#  '__node_nOM1b': <pykat.node_network.Node at 0x7fa6186a02b0>,
#  '__node_nOM2a': <pykat.node_network.Node at 0x7fa6184c4550>,
#  '__node_nOM2b': <pykat.node_network.Node at 0x7fa6186a0ba8>,
#  '__node_nOM3a': <pykat.node_network.Node at 0x7fa6184c4470>,
#  '__node_nOM3b': <pykat.node_network.Node at 0x7fa6184c4c18>,
#  '__node_nOM3trans': <pykat.node_network.Node at 0x7fa6186a1f98>,
#  '__node_nOMC_ARIC2_in': <pykat.node_network.Node at 0x7fa6186a1518>,
#  '__node_nOMC_ARIC_in': <pykat.node_network.Node at 0x7fa6184c4d68>,
#  '__node_nOMC_ARIC_trans': <pykat.node_network.Node at 0x7fa6186a0cf8>,
#  '__node_nOMC_AROC_in': <pykat.node_network.Node at 0x7fa6184c4b38>,
#  '__node_nOMC_AROC_trans': <pykat.node_network.Node at 0x7fa6186a05c0>,
#  '__node_nOMC_CM1_in': <pykat.node_network.Node at 0x7fa6184c4cc0>,
#  '__node_nOMC_CM1_refl': <pykat.node_network.Node at 0x7fa6186a11d0>,
#  '__node_nOMC_CM2_in': <pykat.node_network.Node at 0x7fa6186a1908>,
#  '__node_nOMC_CM2_refl': <pykat.node_network.Node at 0x7fa6186a0ef0>,
#  '__node_nOMC_HRIC_in': <pykat.node_network.Node at 0x7fa6184c4240>,
#  '__node_nOMC_HRIC_trans': <pykat.node_network.Node at 0x7fa6186a0d30>,
#  '__node_nOMC_HRICret': <pykat.node_network.Node at 0x7fa6184c4908>,
#  '__node_nOMC_HROC_in': <pykat.node_network.Node at 0x7fa6186a12b0>,
#  '__node_nOMC_HROC_refl': <pykat.node_network.Node at 0x7fa6186a0828>,
#  '__node_nOMC_HROC_ret': <pykat.node_network.Node at 0x7fa6186a13c8>,
#  '__node_nOMC_HROC_trans': <pykat.node_network.Node at 0x7fa6186a15f8>,
#  '__node_nOPa': <pykat.node_network.Node at 0x7fa6184c4b70>,
#  '__node_nOPb': <pykat.node_network.Node at 0x7fa6184c4048>,
#  '__node_nOPc': <pykat.node_network.Node at 0x7fa6186a1198>,
#  '__node_nOPd': <pykat.node_network.Node at 0x7fa6186a10b8>,
#  '__node_nOPe': <pykat.node_network.Node at 0x7fa6186a17f0>,
#  '__node_nOPf': <pykat.node_network.Node at 0x7fa6186a1e10>,
#  '__node_nPOP': <pykat.node_network.Node at 0x7fa6186a1b38>,
#  '__node_nPOX': <pykat.node_network.Node at 0x7fa6186a1eb8>,
#  '__node_nPR2a': <pykat.node_network.Node at 0x7fa6186a0400>,
#  '__node_nPR2b': <pykat.node_network.Node at 0x7fa6184c4dd8>,
#  '__node_nPR3a': <pykat.node_network.Node at 0x7fa6184c45c0>,
#  '__node_nPR3b': <pykat.node_network.Node at 0x7fa6184c4fd0>,
#  '__node_nPRBS': <pykat.node_network.Node at 0x7fa6184c4668>,
#  '__node_nPRMARb': <pykat.node_network.Node at 0x7fa6184c45f8>,
#  '__node_nPRMHRa': <pykat.node_network.Node at 0x7fa6186a19b0>,
#  '__node_nPRMHRb': <pykat.node_network.Node at 0x7fa6186a0780>,
#  '__node_nPTX': <pykat.node_network.Node at 0x7fa6186a18d0>,
#  '__node_nPTY': <pykat.node_network.Node at 0x7fa6186a1a58>,
#  '__node_nREFL': <pykat.node_network.Node at 0x7fa6186a1fd0>,
#  '__node_nROTb': <pykat.node_network.Node at 0x7fa6184c4be0>,
#  '__node_nROTin': <pykat.node_network.Node at 0x7fa6186a1550>,
#  '__node_nROTouta': <pykat.node_network.Node at 0x7fa6184c4da0>,
#  '__node_nSR2a': <pykat.node_network.Node at 0x7fa6186a04a8>,
#  '__node_nSR2b': <pykat.node_network.Node at 0x7fa6186a1278>,
#  '__node_nSR3a': <pykat.node_network.Node at 0x7fa6184c4588>,
#  '__node_nSR3b': <pykat.node_network.Node at 0x7fa6184c4e80>,
#  '__node_nSRBS': <pykat.node_network.Node at 0x7fa6186a00b8>,
#  '__node_nSRMARa': <pykat.node_network.Node at 0x7fa6186a02e8>,
#  '__node_nSRMARb': <pykat.node_network.Node at 0x7fa6186a1ba8>,
#  '__node_nSRMHRa': <pykat.node_network.Node at 0x7fa6186a0f28>,
#  '__node_nSRMHRb': <pykat.node_network.Node at 0x7fa6186a1ef0>,
#  '__node_nWPa': <pykat.node_network.Node at 0x7fa6186a1e80>,
#  '__node_nWPb': <pykat.node_network.Node at 0x7fa6184c4160>,
#  '__node_nXBS': <pykat.node_network.Node at 0x7fa6186a0b00>,
#  '__node_nYBS': <pykat.node_network.Node at 0x7fa6186a1240>,
#  '__node_nlensFC1a': <pykat.node_network.Node at 0x7fa6186a0898>,
#  '__node_nlensFC1b': <pykat.node_network.Node at 0x7fa6186a1cc0>,
#  '__node_nlensFC2a': <pykat.node_network.Node at 0x7fa6186a1978>,
#  '__node_nlensFC2b': <pykat.node_network.Node at 0x7fa6186a16a0>,
#  '__node_nsqz': <pykat.node_network.Node at 0x7fa6186a1358>}

# %%
 comp_node_list.index(['sMC1toMC2', 'nMC1trans', 'nMC2in'])
# Out:
# 75

# %%
comp_node_list[90][2]
# Out:
# 'nIM1refl'

# %%
###Lock in the components' node q-parameters with the gauss command

katfile1 = './aLIGO_IFO_AWC_tuning_DCoff_maxtem4.kat'
basekat1 = pykat.finesse.kat()
basekat1.loadKatFile(katfile)
basekat1.parseCommands("""
tf sus 1 0 p $mech_fres $mech_Q
const mech_fres 1  # Approx. resonance frequency
const mech_Q    1M # Guess for suspension Q factor

# Differentially modulate the strain in the arms
fsig darm  LXarm 1 0 1
fsig darm2 LYarm 1 180 1

#sq sqz 0 10 0 nsqz

qnoisedS NSR_with_RP    1 $fs nOMC_AROC_trans
xaxis darm f log 5 5k 50
yaxis re:im
""")

for i in range(0,5,1):
    comp = comp_node_list[i][0]
    node1 = comp_node_list[i][1]
    node2 = comp_node_list[i][2]
    qx1 = trace_out[1][0][node1][0]._gauss_param__q
    qy1 = trace_out[1][0][node1][1]._gauss_param__q
    qx2 = trace_out[1][0][node2][0]._gauss_param__q
    qy2 = trace_out[1][0][node2][1]._gauss_param__q
    
    real_qx1 = str(float(np.real(qx1)))
    imag_qx1 = str(float(np.imag(qx1)))
    
    real_qy1 = str(float(np.real(qy1)))
    imag_qy1 = str(float(np.imag(qy1)))
        
    real_qx2 = str(float(np.real(qx2)))
    imag_qx2 = str(float(np.imag(qx2)))
    
    real_qy2 = str(float(np.real(qy2)))
    imag_qy2 = str(float(np.imag(qy2)))
    
    #gauss* name component node q [qy]
    gauss1 = "gauss* " + "gaussina" + str(i) + " " + comp + " " + node1\
    + " " + real_qx1 + " " + imag_qx1 + " " + real_qy1 + " " + imag_qy1
    gauss2 = "gauss* " + "gaussinb" + str(i) + " " + comp + " " + node2\
    + " " + real_qx2 + " " + imag_qx2 + " " + real_qy2 + " " + imag_qy2
    print(gauss1)
    print(gauss2)
    try:
        basekat1.parseCommands(gauss1)
        #basekat1.parseCommands(gauss2)
    except:
        continue

    
#basekat1.parseCommands('startnode n0')

basekat1.undumpNodes() #undump the vacuum nodes

kat1=basekat1.deepcopy() #copy kat code

out_frozenq = kat1.run()

trace_out_frozenq = kat1.run(getTraceData=True)
# Out:
# Parsing `put lx1 L $Lmx` into pykat object not implemented yet, added as extra line.
# Parsing `put ly1 L $Lmy` into pykat object not implemented yet, added as extra line.
# gauss* gaussina0 ETMYsub nETMYs1 2203.87115214173 301.069230104416 2203.87115214173 301.069230104416
# gauss* gaussinb0 ETMYsub nETMYs2 2204.07115214173 301.069230104416 2204.07115214173 301.069230104416
# gauss* gaussina1 SRMHR nSRMHRa 4.73320343361546 2.13229898614863 4.92993692424945 1.94056609838815
# gauss* gaussinb1 SRMHR nSRMHRb -5.19234236268324 1.61361077504175 -5.30281030037173 1.43991118008301
# gauss* gaussina2 OP nOPd -4.07351992797272 1.61361077504175 -4.18398786566121 1.43991118008301
# gauss* gaussinb2 OP nOPb -4.07351992797272 1.61361077504175 -4.18398786566121 1.43991118008301
# gauss* gaussina3 IMFC nIMFC1 8.0445432085806 8.00861649683913 9.09415227937417 8.35254958804968
# gauss* gaussinb3 IMFC nIMFC2 -8.04443929675661 7.99014112676497 -8.98661504852923 7.53200586826001
# gauss* gaussina4 lp3 nPR3b -1373.3154024107 229.923468163986 -1376.08516085118 221.879189423511
# gauss* gaussinb4 lp3 nPRBS -1353.7773024107 229.923468163986 -1356.54706085118 221.879189423511
# --------------------------------------------------------------
# Running kat - Started at 2016-08-23 17:16:46.737690
#  99% | ETA:  0:00:00 | Calculating
# Finished in 12.7425 seconds
# --------------------------------------------------------------
# Running kat - Started at 2016-08-23 17:16:59.480380
#
# Finished in 13.6863 seconds
#  99% | ETA:  0:00:00 | Calculating

# %%
dict_frozenq = trace_out_frozenq[1][0]
print(dict_frozenq, outdict)
# Out:
# {'n6': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa612c9abe0>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa612c9a7f0>), 'dump_31': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bb128>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bb208>), 'nOPe': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf048>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf080>), 'dump_36': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bc710>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bc748>), 'nITMXconstL_trans': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6182b52e8>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619152f28>), 'dump_6': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa61907bac8>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6182b5780>), 'nITMXconstL_in': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6182b5ac8>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619152b00>), 'nAOE1trans': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6191a1198>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6191a1240>), 'nSRMHRa': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa619003390>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6190039e8>), 'nOMC_CM1_refl': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa619285278>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619285da0>), 'nIMFC4': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf668>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf780>), 'nPOP': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bfe80>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bfeb8>), 'nITMYconstL_in': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa612cdb978>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa618665320>), 'nYBS': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6185f7198>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa612cdbe48>), 'dump_35': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa619035be0>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619035f60>), 'nEMFC1': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf518>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf5f8>), 'n5': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa619080ef0>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619080128>), 'nREFL': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6185ea5f8>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6185ea828>), 'dump_28': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf748>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bf828>), 'nAOE1in': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6191a1588>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6191a1c88>), 'nETMXs2': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa61863f198>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa618629cf8>), 'dump_25': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bc5f8>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bc630>), 'nOMC_HRIC_trans': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6181bbf60>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa6192855f8>), 'dump_12': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa619285630>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619285668>), 'nIM2in': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa6191a1828>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa618636518>), 'dump_16': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa619285ac8>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa619285470>), 'dump_37': (<pykat.optics.gaussian_beams.beam_param object at 0x7fa618659630>, <pykat.optics.gaussian_beams.beam_param object at 0x7fa618659588>), 'nOMC_HROC_ref ...

# %%
# [access object][trace data]
dict_frozenq = trace_out_frozenq[1][0]

#parse the output to name and q's
dictlist_frozenq = []
for key, value in dict_frozenq.items():
    temp = [key,value]
    dictlist_frozenq.append(temp)

nodename_list_fq = []
q_x_list_fq = []
q_y_list_fq = []

#[node_list][key/parameters][x/y]
for i in range(len(dictlist_frozenq)):
    nodename_list_fq.append(dictlist[i][0])
    q_x_list_fq.append(dictlist_frozenq[i][1][0]._gauss_param__q)
    q_y_list_fq.append(dictlist_frozenq[i][1][1]._gauss_param__q)
    
#test to see if the nodes match up
for i in range(len(nodename_list)):
    if nodename_list[i] != nodename_list_fq[i]:
        print('Untrue! Double check nodenames!')
    else:
        continue

compare_listx=[]
for i in range(len(nodename_list_fq)):
    if q_x_list_fq[i] != q_x_list[i]:
        compare_listx.append([nodename_list_fq[i], q_x_list[i], q_x_list_fq[i]])
    else:
        continue

compare_listy=[]
for i in range(len(nodename_list_fq)):
    if q_y_list_fq[i] != q_y_list[i]:
        compare_listy.append([nodename_list_fq[i], q_y_list[i], q_y_list_fq[i]])
    else:
        continue

# %%
compare_listy
# Out:
# [['dump_12',
#   (0.329035652338272+0.872249454489459j),
#   (0.630124963065479+1.07145484398937j)],
#  ['nWPa',
#   (-4.77401921628768+1.64733998681461j),
#   (-4.77401921628768+2.38803509572047j)],
#  ['nPTY',
#   (1520.43600582519+207.686805959968j),
#   (-1520.16007353429+301.069230104415j)],
#  ['nETMYs2',
#   (2204.07115214173+301.069230104416j),
#   (-2203.67115214173+436.439286052368j)],
#  ['nWPb',
#   (-2.87858568568894+0.993294976553312j),
#   (-2.87858568568894+1.43991118008301j)],
#  ['dump_19',
#   (1.0467691929798+0.792727194492012j),
#   (0.798115999843369+0.678101158720466j)],
#  ['nOMC_ARIC2_in',
#   (-0.315769192979805+0.792727194492012j),
#   (-0.0671159998433687+0.678101158720466j)],
#  ['dump_22',
#   (-0.219769192979805+0.792727194492012j),
#   (0.0288840001566313+0.678101158720466j)],
#  ['nOMC_ARIC_trans',
#   (-0.318584232759841+1.14916190763965j),
#   (0.0418711417381467+0.982996453940525j)],
#  ['nOM1b',
#   (-0.329035652338272+0.872249454489459j),
#   (-0.630124963065479+1.07145484398937j)],
#  ['nOMC_ARIC_in',
#   (-0.219769192979805+0.792727194492012j),
#   (0.0288840001566313+0.678101158720466j)],
#  ['nOMC_HRIC_in',
#   (-0.307804232759841+1.14916190763965j),
#   (0.0526511417381467+0.982996453940525j)],
#  ['nETMYs1',
#   (2203.87115214173+301.069230104416j),
#   (2203.87115214173+436.439286052368j)],
#  ['nOM2a',
#   (1.06596434766173+0.872249454489459j),
#   (0.764875036934521+1.07145484398937j)],
#  ['dump_18',
#   (1.06596434766173+0.872249454489459j),
#   (0.764875036934521+1.07145484398937j)],
#  ['dump_7',
#   (0.415769192979805+0.792727194492012j),
#   (0.167115999843369+0.678101158720466j)],
#  ['dump_11',
#   (0.0552706143110608+0.993294976553312j),
#   (0.0552706143110608+1.43991118008301j)],
#  ['nOM1a',
#   (0.0552706143110608+0.993294976553312j),
#   (0.0552706143110608+1.43991118008301j)],
#  ['nOPd',
#   (-4.18398786566121+1.43991118008301j),
#   (-4.18398786566121+2.08733986929286j)],
#  ['nOBAin',
#   (-2.66872938568894+0.993294976553312j),
#   (-2.66872938568894+1.43991118008301j)],
#  ['nOM3trans',
#   (-0.415769192979805+0.792727194492012j),
#   (-0.167115999843369+0.678101158720466j)],
#  ['nOM2b',
#   (-1.0467691929798+0.792727194492012j),
#   (-0.798115999843369+0.678101158720466j)],
#  ['nOFIout',
#   (-4.78671921628768+1.64733998681461j),
#   (-4.78671921628768+2.38803509572047j)],
#  ['nOPf',
#   (-4.18398786566121+1.43991118008301j),
#   (-4.18398786566121+2.08733986929286j)],
#  ['dump_23',
#   (0.318584232759841+1.14916190763965j),
#   (-0.0418711417381467+0.982996453940525j)],
#  ['dump_8',
#   (-0.307804232759841+1.14916190763965j),
#   (0.0526511417381467+0.982996453940525j)],
#  ['nOM3b',
#   (-0.415769192979805+0.792727194492012j),
#   (-0.167115999843369+0.678101158720466j)],
#  ['nOM3a',
#   (-0.415769192979805+0.792727194492012j),
#   (-0.167115999843369+0.678101158720466j)],
#  ['nOBAout',
#   (-2.66872938568894+0.993294976553312j),
#   (-2.66872938568894+1.43991118008301j)]]

# %%
for i in range(len(nodename_list)):
    if nodename_list[i] != nodename_list_fq[i]:
        print('Untrue! Double check nodenames!')
    else:
        continue

# %%
plt.figure(figsize=(14,7))



plt.loglog(out.x,out['NSR_with_RP'], label='Finesse QM limited Sensitivity')
plt.loglog(out.x,out_frozenq['NSR_with_RP'], label='Finesse QM limited Sensitivity frozen Q')

plt.title('GW detector: quantum-noise limited sensitivity')
plt.xlabel('signal frequency [Hz]')
plt.xlim([min(out.x),max(out.x)])

plt.legend()
plt.ylabel('sensitivity [1/sqrt(Hz)]')
plt.grid(True)
# Out:
# /home/thomasvo/anaconda3/lib/python3.5/site-packages/numpy/core/numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
