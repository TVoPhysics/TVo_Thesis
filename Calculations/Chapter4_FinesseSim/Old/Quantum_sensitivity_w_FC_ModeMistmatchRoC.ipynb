# %%
# %matplotlib inline
import pykat
import pylab as pl
import pandas
import matplotlib.pyplot as plt
import matplotlib
import csv
import math
import numpy as np
from pykat.parallel import parakat
import pprint

pandas.set_eng_float_format(accuracy=3, use_eng_prefix=True)

# %%
katfile = './aLIGO_IFO_AWC_tuning_DCoff_maxtem2.kat'
basekat = pykat.finesse.kat()
basekat.loadKatFile(katfile)
# Don't need these things so removing them
#basekat.removeLine("startnode")
#basekat.removeBlock('locks',True)
#basekat.removeBlock('ASuWFS',True)
#basekat.removeBlock('REFLWFS',True)


# Add QM noise detectors
basekat.parseCommands("""
tf sus 1 0 p $mech_fres $mech_Q
const mech_fres 1  # Approx. resonance frequency
const mech_Q    1M # Guess for suspension Q factor

# Differentially modulate the strain in the arms
fsig darm  LXarm 1 0 1
fsig darm2 LYarm 1 180 1

#fsig darm  ETMXHR 1 0 .5
#fsig darm2 ETMYHR 1 180 .5

sq sqz 0 10 0 nsqz

qnoisedS NSR_with_RP    1 $fs nOMC_AROC_trans
qshotS   NSR_without_RP 1 $fs nOMC_AROC_trans
#qnoised noise    $fs nOMCout
#pd1     signal 1 $fs nOMCout
#pdS3 power $f1 max $f2 max $fs max nOMCout
#pdS sense


xaxis darm f log 5 5k 50
yaxis log abs
""")

basekat.undumpNodes() #undump the vacuum nodes
kat=basekat.deepcopy() #copy kat code

out = kat.run(getTraceData=True)
# Out:
# Parsing `put lx1 L $Lmx` into pykat object not implemented yet, added as extra line.
# Parsing `put ly1 L $Lmy` into pykat object not implemented yet, added as extra line.
# --------------------------------------------------------------
# Running kat - Started at 2016-08-17 22:29:23.737909
#
# Finished in 2.64557 seconds
#  99% | ETA:  0:00:00 | Calculating

# %%
out

pk = parakat() #enable parallel python processing

vary_fc_T = []
darm_list = []

for i in range(0,10,1):
    f = float(i)*(1e-6)
    vary_fc_T.append(float(f))
    
for i in range(0,10,1):
    basekat.undumpNodes()
    kat=basekat.deepcopy()
    vary = float(vary_fc_T[i])
    f_new = (1/baseline_f - vary)**(-1)
    kat.EMFC.Rc.value = f_new
    print(vary)
    pk.run(kat, cmd_args=["-cr=on"])
    #darm_list.append(out['NSR_with_RP'])

outs = pk.getResults()
# Out:
# [<pykat.finesse.katRun at 0x7f70ef19f0f0>,
#  [{'dump_0': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f0261c18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f0261f60>),
#    'dump_1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a23c8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a28d0>),
#    'dump_10': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573d30>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573748>),
#    'dump_11': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5737f0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5739b0>),
#    'dump_12': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573eb8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573be0>),
#    'dump_13': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a21d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a26a0>),
#    'dump_14': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e17b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef586cc0>),
#    'dump_15': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573518>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573d68>),
#    'dump_16': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb400>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb6d8>),
#    'dump_17': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2eb8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2d30>),
#    'dump_18': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2748>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a20f0>),
#    'dump_19': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2a20>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2080>),
#    'dump_2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2c18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2128>),
#    'dump_20': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbe80>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbeb8>),
#    'dump_21': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2d68>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a25f8>),
#    'dump_22': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2fd0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2e10>),
#    'dump_23': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb438>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbfd0>),
#    'dump_24': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb908>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cba90>),
#    'dump_25': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e05c0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef670390>),
#    'dump_26': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573438>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573668>),
#    'dump_27': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb8d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb630>),
#    'dump_28': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb518>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb080>),
#    'dump_29': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5730b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573e10>),
#    'dump_3': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573630>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573080>),
#    'dump_30': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573ac8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573cf8>),
#    'dump_31': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5737b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573ef0>),
#    'dump_32': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5738d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573da0>),
#    'dump_33': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5739e8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573cc0>),
#    'dump_34': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5734a8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5736a0>),
#    'dump_35': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573320>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5736d8>),
#    'dump_36': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f0261160>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef404c50>),
#    'dump_37': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f03802b0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f0380c18>),
#    'dump_4': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573198>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573a90>),
#    'dump_5': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573908>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573ba8>),
#    'dump_6': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573dd8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573b70>),
#    'dump_7': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628630>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef6285f8>),
#    'dump_8': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573358>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573160>),
#    'dump_9': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573940>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573b00>),
#    'n0': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e93c8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9470>),
#    'n1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef818898>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9eb8>),
#    'n2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef818438>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef818da0>),
#    'n3': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef8181d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef818ba8>),
#    'n4': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef8010b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef818208>),
#    'n5': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef801358>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef801b38>),
#    'n6': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f01a3f60>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f01a35f8>),
#    'nAOE1in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef683160>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef683588>),
#    'nAOE1trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef404128>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef683a58>),
#    'nAOE2in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f01ca470>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5edeb8>),
#    'nAOE2trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f01cadd8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f01ca940>),
#    'nBSi1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e1390>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e1f98>),
#    'nBSi2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e1d68>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e11d0>),
#    'nBSi3': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ab208>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ab588>),
#    'nBSi4': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ab518>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e02b0>),
#    'nEMFC1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2dd8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2ac8>),
#    'nEMFC2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2208>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2978>),
#    'nETMX1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef608dd8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef608198>),
#    'nETMXs1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef608be0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef130208>),
#    'nETMXs2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef608b70>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef1302e8>),
#    'nETMY1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef134208>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef518908>),
#    'nETMYs1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef518860>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef518a90>),
#    'nETMYs2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef518ba8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e1860>),
#    'nIBAin': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628d68>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628400>),
#    'nIBAout': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628128>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628320>),
#    'nIM1ARin': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573c18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573828>),
#    'nIM1ARtrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573f60>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573e48>),
#    'nIM1HRtrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573978>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573a58>),
#    'nIM1in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4044e0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4049b0>),
#    'nIM1refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef404240>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef404668>),
#    'nIM2in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef378c18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef378160>),
#    'nIM2refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef378470>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3785f8>),
#    'nIM3in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f01ca128>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f01caf98>),
#    'nIM3refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3787f0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f01ca6a0>),
#    'nIM4in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ed518>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ed320>),
#    'nIM4refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5edd68>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ed2b0>),
#    'nIM4rettrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5732e8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5733c8>),
#    'nIM4trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573278>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5732b0>),
#    'nIMFC1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2518>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2668>),
#    'nIMFC2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2940>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2908>),
#    'nIMFC3': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2828>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2a90>),
#    'nIMFC4': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2ba8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573588>),
#    'nIOT2Lnanoscan': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573780>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573e80>),
#    'nIPtrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628240>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628668>),
#    'nITMX1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b95f8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef65a8d0>),
#    'nITMX11': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b9dd8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b9438>),
#    'nITMX2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef65ac18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef608860>),
#    'nITMXTLtrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5861d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b9240>),
#    'nITMXconstL_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b9be0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b93c8>),
#    'nITMXconstL_trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b9a90>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7b9d30>),
#    'nITMXs1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef65a390>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef65a588>),
#    'nITMXs2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef65a080>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef65a048>),
#    'nITMY1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef795b38>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7951d0>),
#    'nITMY11': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cf550>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef64c3c8>),
#    'nITMY2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef134630>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5184a8>),
#    'nITMYTLtrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cfb38>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cf4e0>),
#    'nITMYconstL_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cf048>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef64c2b0>),
#    'nITMYconstL_trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef64c0f0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef795668>),
#    'nITMYs1': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef795fd0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef1344e0>),
#    'nITMYs2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef134320>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef1347b8>),
#    'nMC1fromMC3': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9ba8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9d68>),
#    'nMC1in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef8015c0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef801048>),
#    'nMC1refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9278>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9630>),
#    'nMC1trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f01a3748>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f01a3358>),
#    'nMC2in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef301240>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef301668>),
#    'nMC2refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bd470>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bd2b0>),
#    'nMC2trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bd3c8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02613c8>),
#    'nMC3ARin': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f0261fd0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02619e8>),
#    'nMC3ARtrans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f0261588>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4047b8>),
#    'nMC3in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bd748>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bd1d0>),
#    'nMC3refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef7e9908>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bda90>),
#    'nMC3trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3bdd30>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02619b0>),
#    'nMCreturn_refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f0380908>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f0380cc0>),
#    'nOBAin': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7eb8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f75c0>),
#    'nOBAout': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7320>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7390>),
#    'nOFIin': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628550>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef6286d8>),
#    'nOFIout': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef6283c8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628c50>),
#    'nOFIout2': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2358>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a22e8>),
#    'nOM1a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7f98>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7978>),
#    'nOM1b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7b38>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7ef0>),
#    'nOM2a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb278>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb860>),
#    'nOM2b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb1d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb048>),
#    'nOM3a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb7b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb898>),
#    'nOM3b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbb00>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb390>),
#    'nOM3trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2470>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2cc0>),
#    'nOMC_ARIC2_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2400>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2630>),
#    'nOMC_ARIC_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbf60>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb470>),
#    'nOMC_ARIC_trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbba8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbd68>),
#    'nOMC_AROC_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb2e8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a27b8>),
#    'nOMC_AROC_trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2240>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2a58>),
#    'nOMC_CM1_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb978>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbac8>),
#    'nOMC_CM1_refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbe48>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cba20>),
#    'nOMC_CM2_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb748>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb208>),
#    'nOMC_CM2_refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbc18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb550>),
#    'nOMC_HRIC_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb940>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb5f8>),
#    'nOMC_HRIC_trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbb38>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbda0>),
#    'nOMC_HRICret': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cba58>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb588>),
#    'nOMC_HROC_in': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb4a8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb3c8>),
#    'nOMC_HROC_refl': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb9b0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb668>),
#    'nOMC_HROC_ret': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2278>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2710>),
#    'nOMC_HROC_trans': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02cbc88>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02cb780>),
#    'nOPa': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef6289b0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628898>),
#    'nOPb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef6288d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628e80>),
#    'nOPc': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2e80>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2160>),
#    'nOPd': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628ac8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628b70>),
#    'nOPe': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a20b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2320>),
#    'nOPf': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628b38>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628e48>),
#    'nPOP': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef573048>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef573710>),
#    'nPOX': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ab630>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ab5c0>),
#    'nPR2a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef14bb70>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef14b3c8>),
#    'nPR2b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef646518>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef646710>),
#    'nPR3a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef646080>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef646828>),
#    'nPR3b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef6462b0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cfe48>),
#    'nPRBS': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cf668>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cfe10>),
#    'nPRMARb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ed4a8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ed358>),
#    'nPRMHRa': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef14b0f0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef14b128>),
#    'nPRMHRb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef14b860>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef646128>),
#    'nPTX': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef130940>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ab908>),
#    'nPTY': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e10b8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e1940>),
#    'nREFL': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ede10>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5ed9e8>),
#    'nROTb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628f28>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628a90>),
#    'nROTin': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628908>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628518>),
#    'nROTouta': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628860>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628710>),
#    'nSR2a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef84d438>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef84d4e0>),
#    'nSR2b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef670b38>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef84d6a0>),
#    'nSR3a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef6701d0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef670c88>),
#    'nSR3b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef670048>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef670438>),
#    'nSRBS': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef670d30>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef670cf8>),
#    'nSRMARa': (<pykat.optics.gaussian_beams.beam_param at 0x7f70f02e5f98>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02e5358>),
#    'nSRMARb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628c18>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628da0>),
#    'nSRMHRa': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef84d668>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef84d1d0>),
#    'nSRMHRb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef84d898>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70f02e59b0>),
#    'nWPa': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628748>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef5f7198>),
#    'nWPb': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef628a20>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef628390>),
#    'nXBS': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef5e1a20>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef586828>),
#    'nYBS': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cf4a8>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef3cf7b8>),
#    'nlensFC1a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2ef0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2588>),
#    'nlensFC1b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2550>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2e48>),
#    'nlensFC2a': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a24e0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2f60>),
#    'nlensFC2b': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2f28>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a2be0>),
#    'nsqz': (<pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a27f0>,
#     <pykat.optics.gaussian_beams.beam_param at 0x7f70ef4a29e8>)}]]

# %%
for i,out in enumerate(outs):
    darm_list.append(outs[i]['NSR_with_RP'])
    
hbar=6.62606957E-34/(2.0 *np.pi)
m = 40.
L = 3994.5
SQL_x = np.sqrt( 8 * hbar / ( m * (2*np.pi*out.x)**2)) / L

# %%
vars(out[1][0]['nSRMHRa'][0])
# Out:
# {'_gauss_param__lambda': 1.064e-06,
#  '_gauss_param__nr': 1.0,
#  '_gauss_param__q': (4.73320343361546+2.13229898614863j)}

# %%
pk.clear()
pk.close()

# %%
gwinc_data = np.genfromtxt('./GwincOutput125W.csv', delimiter=',')
headers = ['Freq','MirrorThermal','Newtonian','Quantum','ResGas','Seismic','SuspThermal','Total']

Freq = []
MirrorThermal = []
Newtonian = []
Quantum = []
ResGas = []
Seismic = []
SuspThermal = []
Total = []
for i in range(len(gwinc_data)):
    Freq.append(gwinc_data[i][0])
    MirrorThermal.append(math.sqrt(gwinc_data[i][1]))
    Newtonian.append(math.sqrt(gwinc_data[i][2]))
    Quantum.append(math.sqrt(gwinc_data[i][3]))
    ResGas.append(math.sqrt(gwinc_data[i][4]))
    Seismic.append(math.sqrt(gwinc_data[i][5]))
    SuspThermal.append(math.sqrt(gwinc_data[i][6]))
    Total.append(math.sqrt(gwinc_data[i][7]))

# %%
plt.figure(figsize=(14,7))

plt.loglog(out.x,out['NSR_with_RP'], label='Finesse QM limited Sensitivity')
#plt.loglog(out.x,darm_list[2], label='10db')

#plt.loglog(out.x,out['NSR_without_RP'],label='Finesse ShotNoise')
plt.loglog(out.x,SQL_x,'-.',color='k', label='SQL')
#plt.loglog(out.x,out['power'],label='Power on PD')
#plt.loglog(out.x,out['sense'],label='Finesse Total')
plt.loglog(Freq,Quantum,label='GwincQM noise')
#plt.loglog(Freq,Total,label='Gwinc total noise')
plt.title('GW detector: quantum-noise limited sensitivity')
plt.xlabel('signal frequency [Hz]')
plt.xlim([min(out.x),max(out.x)])
plt.ylim([1E-24,2E-22])
plt.legend()
plt.ylabel('sensitivity [1/sqrt(Hz)]')
plt.grid(True)

# %%
len(darm_list)
# Out:
# 10

# %%
matplotlib.RcParams.update({'font.size', 'Large'})

pl.figure(figsize=(9, 5), dpi=80)

cm = pl.cm.Spectral_r
norm = matplotlib.colors.Normalize(0, 1e-5)

s_m = matplotlib.cm.ScalarMappable(cmap=cm, norm=norm)
s_m.set_array([])


for i in range(len(darm_list)):
    c = c = s_m.to_rgba(vary_fc_T[i])
    pl.subplot(111)
    pl.loglog(out.x, darm_list[i],linewidth=3,zorder=1000, color = c)
    pl.tick_params(labelsize=10)
    
pl.subplot(111)

#plt.loglog(out.x,SQL_x,'-.',color='k', label='SQL')
plt.loglog(Freq,Quantum,'o',label='Baseline ALIGO')

#pl.loglog(out.x, darm_list[0],out.x, darm_list[1],out.x, darm_list[2],out.x, darm_list[3],out.x, darm_list[4], color = c )
pl.title("Quantum noise varying EMFC RoC", fontsize = 15)
pl.xlim(out.x.min(),out.x.max())
pl.ylim(3e-25,1e-22)
pl.grid(True, zorder=-1)
pl.legend()

pl.xlabel("Frequency [Hz]", fontsize = 10)
pl.ylabel("Strain sensitivity [$1/\\sqrt{\mathrm{Hz}}$]", fontsize = 10)

cb = pl.colorbar(s_m)
cb.set_label("Diopters from nominal in Lens [1/m]", fontsize = 10)
cb.ax.tick_params(labelsize=10) 
cb.formatter.set_powerlimits((1, 0))
cb.update_ticks()

pl.tick_params(labelsize=10)
#pylab.savefig("fc_mismatch_to_sqz_ifo_maxtem_%i_sqzing_%g.pdf" % (maxtem, kat.sqz.db))


pl.show()

# %%
# %time
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 8.58 µs
