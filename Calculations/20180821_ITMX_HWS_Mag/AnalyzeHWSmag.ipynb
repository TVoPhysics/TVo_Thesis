# %%
import numpy as np
import matplotlib.pyplot as pl
from scipy.optimize import leastsq

# %matplotlib inline

# %%
OL_P = np.loadtxt('20180821_ITMX_HWS_MAG_Oplev_Pit.txt',delimiter=" ")
OL_Y = np.loadtxt('20180821_ITMX_HWS_MAG_Oplev_Yaw.txt',delimiter=" ")

HWS_P = np.loadtxt('20180821_ITMX_HWS_MAG_PRISM_Y.txt',delimiter=" ")
HWS_Y = np.loadtxt('20180821_ITMX_HWS_MAG_PRISM_X.txt',delimiter=" ")

# %%
time = HWS_Y[:,0]

ratio_P = 1e6*HWS_P[:,1]/(OL_P[:,1])
ratio_Y = 1e6*HWS_Y[:,1]/(OL_Y[:,1])

# %%
np.average(ratio_P), np.average(ratio_Y)
# Out:
# (1.2712870554358355, 0.00016085072617486623)

# %%
pl.figure(figsize=(20, 10), dpi=80)

pl.plot(time, ratio)


pl.show()

# %%
pl.figure(figsize=(20, 10), dpi=80)

pl.plot(time_list, ratio_list)

pl.ylim(-20,20)

pl.show()
